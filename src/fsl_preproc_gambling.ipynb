# %%
# !pip install niflow-nipype1-workflows
# Out:
# Collecting niflow-nipype1-workflows
#   Downloading niflow_nipype1_workflows-0.0.5-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: Click in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from niflow-nipype1-workflows) (8.1.3)
# Collecting future>=0.16.0
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: nipype in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from niflow-nipype1-workflows) (1.8.2)
# Requirement already satisfied: networkx>=2.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (2.8.3)
# Requirement already satisfied: rdflib>=5.0.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (6.1.1)
# Requirement already satisfied: prov>=1.5.2 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (2.0.0)
# Requirement already satisfied: scipy>=0.14 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (1.8.1)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (1.22.4)
# Collecting etelemetry>=0.2.0
#   Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.2 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (2.8.2)
# Requirement already satisfied: pydot>=1.2.3 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (1.4.2)
# Requirement already satisfied: packaging in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (21.3)
# Requirement already satisfied: traits!=5.0,>=4.6 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (6.3.2)
# Requirement already satisfied: filelock>=3.0.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (3.7.1)
# Requirement already satisfied: simplejson>=3.8.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (3.17.6)
# Requirement already satisfied: looseversion in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (1.0.1)
# Requirement already satisfied: nibabel>=2.1.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nipype->niflow-nipype1-workflows) (3.2.2)
# Requirement already satisfied: requests in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (2.27.1)
# Requirement already satisfied: ci-info>=0.2 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (0.2.0)
# Requirement already satisfied: setuptools in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from nibabel>=2.1.0->nipype->niflow-nipype1-workflows) (62.3.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from packaging->nipype->niflow-nipype1-workflows) (3.0.9)
# Requirement already satisfied: lxml>=3.3.5 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from prov>=1.5.2->nipype->niflow-nipype1-workflows) (4.9.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from python-dateutil>=2.2->nipype->niflow-nipype1-workflows) (1.16.0)
# Requirement already satisfied: isodate in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from rdflib>=5.0.0->nipype->niflow-nipype1-workflows) (0.6.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from requests->etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from requests->etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from requests->etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda-latest/envs/neuro/lib/python3.8/site-packages (from requests->etelemetry>=0.2.0->nipype->niflow-nipype1-workflows) (3.3)
# Installing collected packages: future, etelemetry, niflow-nipype1-workflows
#   Attempting uninstall: etelemetry
#     Found existing installation: etelemetry 0+unknown
#     Uninstalling etelemetry-0+unknown:
#       Successfully uninstalled etelemetry-0+unknown
# Successfully installed etelemetry-0.3.1 future-1.0.0 niflow-nipype1-workflows-0.0.5

# %%
from lib import spm_pipelines, fsl_pipelines

from os.path import join as opj
import os
from nipype import config
config.enable_debug_mode()
# Out:
# stty: 'standard input': Inappropriate ioctl for device

# %%
exp_dir = '/srv/tempdd/egermani/hcp_pipelines/data/original'
result_dir = '/srv/tempdd/egermani/hcp_pipelines/data/derived'

working_dir = 'fsl_preprocessing/intermediate_results'
output_dir = 'fsl_preprocessing'

#subject_list =["116726","118528","131823","135124","136126","150524","152225","167743","176542"]


subject_list =["131823"]

task_list = ['GAMBLING']

contrast_list = ['win_event', 'neut_event', 'loss_event', 'win', 'loss']

fwhm_list = [5,8] #5, 8

hrf = ['derivatives','no_derivatives'] #'derivatives', 'no_derivatives'

nb_param=[0,6,24]

# %%
for subjects in subject_list:
    preprocess = fsl_pipelines.get_preprocessing(exp_dir, result_dir, working_dir, output_dir, subject_list, task_list, 
                                                fwhm_list)
preprocess.run()
# Out:
# 251107-03:49:44,719 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:49:49,893 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:49:55,69 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:00,243 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:05,488 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:10,659 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:15,837 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:15,840 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.stripper): No edge data
# 251107-03:50:15,842 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.stripper): new edge data: {'connect': [('anatomical_image', 'in_file')]}
# 251107-03:50:21,29 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:21,33 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.fast): No edge data
# 251107-03:50:21,34 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.fast): new edge data: {'connect': [('out_file', 'in_files')]}
# 251107-03:50:26,215 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:26,221 nipype.workflow DEBUG:
# 	 (registration.fast, registration.binarize): No edge data
# 251107-03:50:26,222 nipype.workflow DEBUG:
# 	 (registration.fast, registration.binarize): new edge data: {'connect': [(('partial_volume_files', 'pickindex = lambda x, i: x[i]\n', (2,)), 'in_file')]}
# 251107-03:50:31,531 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:31,540 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anat): No edge data
# 251107-03:50:31,542 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anat): new edge data: {'connect': [('mean_image', 'in_file')]}
# 251107-03:50:31,543 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.mean2anat): No edge data
# 251107-03:50:31,544 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.mean2anat): new edge data: {'connect': [('out_file', 'reference')]}
# 251107-03:50:36,714 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:36,720 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anatbbr): No edge data
# 251107-03:50:36,721 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anatbbr): new edge data: {'connect': [('mean_image', 'in_file')]}
# 251107-03:50:36,722 nipype.workflow DEBUG:
# 	 (registration.binarize, registration.mean2anatbbr): No edge data
# 251107-03:50:36,723 nipype.workflow DEBUG:
# 	 (registration.binarize, registration.mean2anatbbr): new edge data: {'connect': [('out_file', 'wm_seg')]}
# 251107-03:50:36,724 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anatbbr): Edge data exists: {'connect': [('mean_image', 'in_file')]}
# 251107-03:50:36,725 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.mean2anatbbr): new edge data: {'connect': [('mean_image', 'in_file'), ('anatomical_image', 'reference')]}
# 251107-03:50:36,727 nipype.workflow DEBUG:
# 	 (registration.mean2anat, registration.mean2anatbbr): No edge data
# 251107-03:50:36,728 nipype.workflow DEBUG:
# 	 (registration.mean2anat, registration.mean2anatbbr): new edge data: {'connect': [('out_matrix_file', 'in_matrix_file')]}
# 251107-03:50:41,895 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:41,900 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.anat2target_linear): No edge data
# 251107-03:50:41,901 nipype.workflow DEBUG:
# 	 (registration.stripper, registration.anat2target_linear): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:50:41,902 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_linear): No edge data
# 251107-03:50:41,903 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_linear): new edge data: {'connect': [('target_image_brain', 'reference')]}
# 251107-03:50:47,74 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:47,80 nipype.workflow DEBUG:
# 	 (registration.anat2target_linear, registration.anat2target_nonlinear): No edge data
# 251107-03:50:47,81 nipype.workflow DEBUG:
# 	 (registration.anat2target_linear, registration.anat2target_nonlinear): new edge data: {'connect': [('out_matrix_file', 'affine_file')]}
# 251107-03:50:47,82 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): No edge data
# 251107-03:50:47,83 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): new edge data: {'connect': [('anatomical_image', 'in_file')]}
# 251107-03:50:47,84 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): Edge data exists: {'connect': [('anatomical_image', 'in_file')]}
# 251107-03:50:47,85 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): new edge data: {'connect': [('anatomical_image', 'in_file'), ('config_file', 'config_file')]}
# 251107-03:50:47,86 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): Edge data exists: {'connect': [('anatomical_image', 'in_file'), ('config_file', 'config_file')]}
# 251107-03:50:47,88 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.anat2target_nonlinear): new edge data: {'connect': [('anatomical_image', 'in_file'), ('config_file', 'config_file'), ('target_image', 'ref_file')]}
# 251107-03:50:52,262 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:52,266 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpmean): No edge data
# 251107-03:50:52,267 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpmean): new edge data: {'connect': [('mean_image', 'in_file')]}
# 251107-03:50:52,268 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.warpmean): No edge data
# 251107-03:50:52,269 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.warpmean): new edge data: {'connect': [('out_matrix_file', 'premat')]}
# 251107-03:50:52,269 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpmean): Edge data exists: {'connect': [('mean_image', 'in_file')]}
# 251107-03:50:52,270 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpmean): new edge data: {'connect': [('mean_image', 'in_file'), ('target_image', 'ref_file')]}
# 251107-03:50:52,271 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.warpmean): No edge data
# 251107-03:50:52,271 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.warpmean): new edge data: {'connect': [('fieldcoeff_file', 'field_file')]}
# 251107-03:50:57,428 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:50:57,432 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:50:57,433 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpall): No edge data
# 251107-03:50:57,434 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpall): new edge data: {'connect': [('source_files', 'in_file')]}
# 251107-03:50:57,435 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.warpall): No edge data
# 251107-03:50:57,436 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.warpall): new edge data: {'connect': [('out_matrix_file', 'premat')]}
# 251107-03:50:57,438 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpall): Edge data exists: {'connect': [('source_files', 'in_file')]}
# 251107-03:50:57,439 nipype.workflow DEBUG:
# 	 (registration.inputspec, registration.warpall): new edge data: {'connect': [('source_files', 'in_file'), ('target_image', 'ref_file')]}
# 251107-03:50:57,440 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.warpall): No edge data
# 251107-03:50:57,441 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.warpall): new edge data: {'connect': [('fieldcoeff_file', 'field_file')]}
# 251107-03:50:57,444 nipype.workflow DEBUG:
# 	 (registration.warpmean, registration.outputspec): No edge data
# 251107-03:50:57,446 nipype.workflow DEBUG:
# 	 (registration.warpmean, registration.outputspec): new edge data: {'connect': [('out_file', 'transformed_mean')]}
# 251107-03:50:57,447 nipype.workflow DEBUG:
# 	 (registration.warpall, registration.outputspec): No edge data
# 251107-03:50:57,448 nipype.workflow DEBUG:
# 	 (registration.warpall, registration.outputspec): new edge data: {'connect': [('out_file', 'transformed_files')]}
# 251107-03:50:57,448 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.outputspec): No edge data
# 251107-03:50:57,450 nipype.workflow DEBUG:
# 	 (registration.mean2anatbbr, registration.outputspec): new edge data: {'connect': [('out_matrix_file', 'func2anat_transform')]}
# 251107-03:50:57,450 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.outputspec): No edge data
# 251107-03:50:57,451 nipype.workflow DEBUG:
# 	 (registration.anat2target_nonlinear, registration.outputspec): new edge data: {'connect': [('fieldcoeff_file', 'anat2target_transform')]}
# 251107-03:50:57,465 nipype.workflow DEBUG:
# 	 [Node] inputspec - setting input target_image = /opt/fsl-6.0.3/data/standard/MNI152_T1_2mm_brain.nii.gz
# 251107-03:50:57,473 nipype.workflow DEBUG:
# 	 [Node] inputspec - setting input target_image_brain = /opt/fsl-6.0.3/data/standard/MNI152_T1_2mm_brain.nii.gz
# 251107-03:51:02,627 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:07,793 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:12,966 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:12,971 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:12,973 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.img2float): No edge data
# 251107-03:51:12,975 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.img2float): new edge data: {'connect': [('func', 'in_file')]}
# 251107-03:51:18,154 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:18,160 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.extractref): No edge data
# 251107-03:51:18,161 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.extractref): new edge data: {'connect': [(('out_file', 'def pickrun(files, whichrun):\n    """pick file from list of files"""\n\n    filemap = {\'first\': 0, \'last\': -1, \'middle\': len(files) // 2}\n\n    if isinstance(files, list):\n\n        # whichrun is given as integer\n        if isinstance(whichrun, int):\n            return files[whichrun]\n        # whichrun is given as string\n        elif isinstance(whichrun, str):\n            if whichrun not in filemap.keys():\n                raise (KeyError, \'Sorry, whichrun must be either integer index\'\n                       \'or string in form of "first", "last" or "middle\')\n            else:\n                return files[filemap[whichrun]]\n    else:\n        # in case single file name is given\n        return files\n', (0,)), 'in_file')]}
# 251107-03:51:18,163 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.extractref): Edge data exists: {'connect': [(('out_file', 'def pickrun(files, whichrun):\n    """pick file from list of files"""\n\n    filemap = {\'first\': 0, \'last\': -1, \'middle\': len(files) // 2}\n\n    if isinstance(files, list):\n\n        # whichrun is given as integer\n        if isinstance(whichrun, int):\n            return files[whichrun]\n        # whichrun is given as string\n        elif isinstance(whichrun, str):\n            if whichrun not in filemap.keys():\n                raise (KeyError, \'Sorry, whichrun must be either integer index\'\n                       \'or string in form of "first", "last" or "middle\')\n            else:\n                return files[filemap[whichrun]]\n    else:\n        # in case single file name is given\n        return files\n', (0,)), 'in_file')]}
# 251107-03:51:18,164 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.extractref): new edge data: {'connect': [(('out_file', 'def pickrun(files, whichrun):\n    """pick file from list of files"""\n\n    filemap = {\'first\': 0, \'last\': -1, \'middle\': len(files) // 2}\n\n    if isinstance(files, list):\n\n        # whichrun is given as integer\n        if isinstance(whichrun, int):\n            return files[whichrun]\n        # whichrun is given as string\n        elif isinstance(whichrun, str):\n            if whichrun not in filemap.keys():\n                raise (KeyError, \'Sorry, whichrun must be either integer index\'\n                       \'or string in form of "first", "last" or "middle\')\n            else:\n                return files[filemap[whichrun]]\n    else:\n        # in case single file name is given\n        return files\n', (0,)), 'in_file'), (('out_file', "def pickvol(filenames, fileidx, which):\n    from nibabel import load\n    import numpy as np\n    if which.lower() == 'first':\n        idx = 0\n    elif which.lower() == 'middle':\n        idx = int(\n            np.ceil(load(filenames[fileidx]).shape[3] / 2))\n    elif which.lower() == 'last':\n        idx = load(filenames[fileidx]).shape[3] - 1\n    else:\n        raise Exception('unknown value for volume selection : %s' % which)\n    return idx\n", (0, 'middle')), 't_min')]}
# 251107-03:51:18,165 nipype.workflow DEBUG:
# 	 (featpreproc.extractref, featpreproc.outputspec): No edge data
# 251107-03:51:18,166 nipype.workflow DEBUG:
# 	 (featpreproc.extractref, featpreproc.outputspec): new edge data: {'connect': [('roi_file', 'reference')]}
# 251107-03:51:23,326 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:23,330 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:23,332 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.realign): No edge data
# 251107-03:51:23,334 nipype.workflow DEBUG:
# 	 (featpreproc.img2float, featpreproc.realign): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:23,338 nipype.workflow DEBUG:
# 	 (featpreproc.extractref, featpreproc.realign): No edge data
# 251107-03:51:23,340 nipype.workflow DEBUG:
# 	 (featpreproc.extractref, featpreproc.realign): new edge data: {'connect': [('roi_file', 'ref_file')]}
# 251107-03:51:23,341 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.outputspec): No edge data
# 251107-03:51:23,342 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.outputspec): new edge data: {'connect': [('par_file', 'motion_parameters')]}
# 251107-03:51:23,343 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.outputspec): Edge data exists: {'connect': [('par_file', 'motion_parameters')]}
# 251107-03:51:23,344 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.outputspec): new edge data: {'connect': [('par_file', 'motion_parameters'), ('out_file', 'realigned_files')]}
# 251107-03:51:28,509 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:28,513 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:28,515 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.plot_motion): No edge data
# 251107-03:51:28,516 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.plot_motion): new edge data: {'connect': [('par_file', 'in_file')]}
# 251107-03:51:28,518 nipype.workflow DEBUG:
# 	 (featpreproc.plot_motion, featpreproc.outputspec): No edge data
# 251107-03:51:28,520 nipype.workflow DEBUG:
# 	 (featpreproc.plot_motion, featpreproc.outputspec): new edge data: {'connect': [('out_file', 'motion_plots')]}
# 251107-03:51:33,692 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:33,698 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.meanfunc): No edge data
# 251107-03:51:33,699 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.meanfunc): new edge data: {'connect': [(('out_file', 'def pickrun(files, whichrun):\n    """pick file from list of files"""\n\n    filemap = {\'first\': 0, \'last\': -1, \'middle\': len(files) // 2}\n\n    if isinstance(files, list):\n\n        # whichrun is given as integer\n        if isinstance(whichrun, int):\n            return files[whichrun]\n        # whichrun is given as string\n        elif isinstance(whichrun, str):\n            if whichrun not in filemap.keys():\n                raise (KeyError, \'Sorry, whichrun must be either integer index\'\n                       \'or string in form of "first", "last" or "middle\')\n            else:\n                return files[filemap[whichrun]]\n    else:\n        # in case single file name is given\n        return files\n', (0,)), 'in_file')]}
# 251107-03:51:38,877 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:38,880 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc, featpreproc.meanfuncmask): No edge data
# 251107-03:51:38,881 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc, featpreproc.meanfuncmask): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:44,52 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:44,56 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:44,58 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.maskfunc): No edge data
# 251107-03:51:44,60 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.maskfunc): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:44,61 nipype.workflow DEBUG:
# 	 (featpreproc.meanfuncmask, featpreproc.maskfunc): No edge data
# 251107-03:51:44,63 nipype.workflow DEBUG:
# 	 (featpreproc.meanfuncmask, featpreproc.maskfunc): new edge data: {'connect': [('mask_file', 'in_file2')]}
# 251107-03:51:49,289 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:49,293 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:49,294 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc, featpreproc.getthreshold): No edge data
# 251107-03:51:49,296 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc, featpreproc.getthreshold): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:54,469 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:54,473 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:54,475 nipype.workflow DEBUG:
# 	 adding multipath trait: op_string
# 251107-03:51:54,482 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc, featpreproc.threshold): No edge data
# 251107-03:51:54,485 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc, featpreproc.threshold): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:54,487 nipype.workflow DEBUG:
# 	 (featpreproc.getthreshold, featpreproc.threshold): No edge data
# 251107-03:51:54,488 nipype.workflow DEBUG:
# 	 (featpreproc.getthreshold, featpreproc.threshold): new edge data: {'connect': [(('out_stat', "def getthreshop(thresh):\n    return ['-thr %.10f -Tmin -bin' % (0.1 * val[1]) for val in thresh]\n", ()), 'op_string')]}
# 251107-03:51:59,651 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:51:59,655 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:51:59,656 nipype.workflow DEBUG:
# 	 adding multipath trait: mask_file
# 251107-03:51:59,658 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.medianval): No edge data
# 251107-03:51:59,661 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.medianval): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:51:59,662 nipype.workflow DEBUG:
# 	 (featpreproc.threshold, featpreproc.medianval): No edge data
# 251107-03:51:59,664 nipype.workflow DEBUG:
# 	 (featpreproc.threshold, featpreproc.medianval): new edge data: {'connect': [('out_file', 'mask_file')]}
# 251107-03:52:04,835 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:04,840 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:04,841 nipype.workflow DEBUG:
# 	 (featpreproc.threshold, featpreproc.dilatemask): No edge data
# 251107-03:52:04,843 nipype.workflow DEBUG:
# 	 (featpreproc.threshold, featpreproc.dilatemask): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:52:04,844 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.outputspec): No edge data
# 251107-03:52:04,845 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.outputspec): new edge data: {'connect': [('out_file', 'mask')]}
# 251107-03:52:10,15 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:10,19 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:10,20 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file2
# 251107-03:52:10,22 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.maskfunc2): No edge data
# 251107-03:52:10,30 nipype.workflow DEBUG:
# 	 (featpreproc.realign, featpreproc.maskfunc2): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:52:10,35 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.maskfunc2): No edge data
# 251107-03:52:10,36 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.maskfunc2): new edge data: {'connect': [('out_file', 'in_file2')]}
# 251107-03:52:15,204 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:20,372 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:25,545 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:25,548 nipype.workflow DEBUG:
# 	 adding multipath trait: brightness_threshold
# 251107-03:52:25,550 nipype.workflow DEBUG:
# 	 adding multipath trait: fwhm
# 251107-03:52:25,551 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:25,552 nipype.workflow DEBUG:
# 	 adding multipath trait: usans
# 251107-03:52:30,725 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:30,728 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:30,730 nipype.workflow DEBUG:
# 	 adding multipath trait: mask_file
# 251107-03:52:30,731 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.median): No edge data
# 251107-03:52:30,734 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.median): new edge data: {'connect': [('in_files', 'in_file')]}
# 251107-03:52:30,735 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.median): Edge data exists: {'connect': [('in_files', 'in_file')]}
# 251107-03:52:30,736 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.median): new edge data: {'connect': [('in_files', 'in_file'), ('mask_file', 'mask_file')]}
# 251107-03:52:35,918 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:35,922 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:35,924 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file2
# 251107-03:52:35,926 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.mask): No edge data
# 251107-03:52:35,927 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.mask): new edge data: {'connect': [('in_files', 'in_file')]}
# 251107-03:52:35,928 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.mask): Edge data exists: {'connect': [('in_files', 'in_file')]}
# 251107-03:52:35,929 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.mask): new edge data: {'connect': [('in_files', 'in_file'), ('mask_file', 'in_file2')]}
# 251107-03:52:41,100 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:41,104 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:41,106 nipype.workflow DEBUG:
# 	 (susan_smooth.mask, susan_smooth.meanfunc2): No edge data
# 251107-03:52:41,107 nipype.workflow DEBUG:
# 	 (susan_smooth.mask, susan_smooth.meanfunc2): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:52:46,279 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:46,292 nipype.workflow DEBUG:
# 	 (susan_smooth.meanfunc2, susan_smooth.merge): No edge data
# 251107-03:52:46,294 nipype.workflow DEBUG:
# 	 (susan_smooth.meanfunc2, susan_smooth.merge): new edge data: {'connect': [('out_file', 'in1')]}
# 251107-03:52:46,295 nipype.workflow DEBUG:
# 	 (susan_smooth.median, susan_smooth.merge): No edge data
# 251107-03:52:46,296 nipype.workflow DEBUG:
# 	 (susan_smooth.median, susan_smooth.merge): new edge data: {'connect': [('out_stat', 'in2')]}
# 251107-03:52:46,298 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.multi_inputs): No edge data
# 251107-03:52:46,299 nipype.workflow DEBUG:
# 	 (susan_smooth.inputnode, susan_smooth.multi_inputs): new edge data: {'connect': [('in_files', 'in_files'), ('fwhm', 'fwhms')]}
# 251107-03:52:46,300 nipype.workflow DEBUG:
# 	 (susan_smooth.median, susan_smooth.multi_inputs): No edge data
# 251107-03:52:46,301 nipype.workflow DEBUG:
# 	 (susan_smooth.median, susan_smooth.multi_inputs): new edge data: {'connect': [(('out_stat', 'def getbtthresh(medianvals):\n    return [0.75 * val for val in medianvals]\n', ()), 'btthresh')]}
# 251107-03:52:46,302 nipype.workflow DEBUG:
# 	 (susan_smooth.merge, susan_smooth.multi_inputs): No edge data
# 251107-03:52:46,303 nipype.workflow DEBUG:
# 	 (susan_smooth.merge, susan_smooth.multi_inputs): new edge data: {'connect': [(('out', 'def getusans(x):\n    return [[tuple([val[0], 0.75 * val[1]])] for val in x]\n', ()), 'usans')]}
# 251107-03:52:46,303 nipype.workflow DEBUG:
# 	 (susan_smooth.multi_inputs, susan_smooth.smooth): No edge data
# 251107-03:52:46,304 nipype.workflow DEBUG:
# 	 (susan_smooth.multi_inputs, susan_smooth.smooth): new edge data: {'connect': [('cart_in_file', 'in_file'), ('cart_fwhm', 'fwhm'), ('cart_btthresh', 'brightness_threshold'), ('cart_usans', 'usans')]}
# 251107-03:52:51,471 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:51,474 nipype.workflow DEBUG:
# 	 (susan_smooth.smooth, susan_smooth.outputnode): No edge data
# 251107-03:52:51,475 nipype.workflow DEBUG:
# 	 (susan_smooth.smooth, susan_smooth.outputnode): new edge data: {'connect': [('smoothed_file', 'smoothed_files')]}
# 251107-03:52:51,477 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.susan_smooth): No edge data
# 251107-03:52:51,478 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.susan_smooth): new edge data: {'connect': [('fwhm', 'inputnode.fwhm')]}
# 251107-03:52:51,479 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc2, featpreproc.susan_smooth): No edge data
# 251107-03:52:51,480 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc2, featpreproc.susan_smooth): new edge data: {'connect': [('out_file', 'inputnode.in_files')]}
# 251107-03:52:51,481 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.susan_smooth): No edge data
# 251107-03:52:51,483 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.susan_smooth): new edge data: {'connect': [('out_file', 'inputnode.mask_file')]}
# 251107-03:52:56,649 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:52:56,653 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:52:56,655 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file2
# 251107-03:52:56,656 nipype.workflow DEBUG:
# 	 (featpreproc.susan_smooth, featpreproc.maskfunc3): No edge data
# 251107-03:52:56,658 nipype.workflow DEBUG:
# 	 (featpreproc.susan_smooth, featpreproc.maskfunc3): new edge data: {'connect': [('outputnode.smoothed_files', 'in_file')]}
# 251107-03:52:56,659 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.maskfunc3): No edge data
# 251107-03:52:56,659 nipype.workflow DEBUG:
# 	 (featpreproc.dilatemask, featpreproc.maskfunc3): new edge data: {'connect': [('out_file', 'in_file2')]}
# 251107-03:53:01,823 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:01,828 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc2, featpreproc.concat): No edge data
# 251107-03:53:01,829 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc2, featpreproc.concat): new edge data: {'connect': [(('out_file', 'tolist = lambda x: [x]\n', ()), 'in1')]}
# 251107-03:53:01,831 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc3, featpreproc.concat): No edge data
# 251107-03:53:01,832 nipype.workflow DEBUG:
# 	 (featpreproc.maskfunc3, featpreproc.concat): new edge data: {'connect': [(('out_file', 'tolist = lambda x: [x]\n', ()), 'in2')]}
# 251107-03:53:07,104 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:07,107 nipype.workflow DEBUG:
# 	 (featpreproc.concat, featpreproc.select): No edge data
# 251107-03:53:07,108 nipype.workflow DEBUG:
# 	 (featpreproc.concat, featpreproc.select): new edge data: {'connect': [('out', 'inlist')]}
# 251107-03:53:07,110 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.select): No edge data
# 251107-03:53:07,111 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.select): new edge data: {'connect': [(('fwhm', 'def chooseindex(fwhm):\n    if fwhm < 1:\n        return [0]\n    else:\n        return [1]\n', ()), 'index')]}
# 251107-03:53:07,113 nipype.workflow DEBUG:
# 	 (featpreproc.select, featpreproc.outputspec): No edge data
# 251107-03:53:07,113 nipype.workflow DEBUG:
# 	 (featpreproc.select, featpreproc.outputspec): new edge data: {'connect': [('out', 'smoothed_files')]}
# 251107-03:53:12,286 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:12,290 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:53:12,291 nipype.workflow DEBUG:
# 	 adding multipath trait: op_string
# 251107-03:53:12,293 nipype.workflow DEBUG:
# 	 (featpreproc.select, featpreproc.meanscale): No edge data
# 251107-03:53:12,295 nipype.workflow DEBUG:
# 	 (featpreproc.select, featpreproc.meanscale): new edge data: {'connect': [('out', 'in_file')]}
# 251107-03:53:12,297 nipype.workflow DEBUG:
# 	 (featpreproc.medianval, featpreproc.meanscale): No edge data
# 251107-03:53:12,301 nipype.workflow DEBUG:
# 	 (featpreproc.medianval, featpreproc.meanscale): new edge data: {'connect': [(('out_stat', "def getmeanscale(medianvals):\n    return ['-mul %.10f' % (10000. / val) for val in medianvals]\n", ()), 'op_string')]}
# 251107-03:53:17,470 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:17,476 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.meanfunc3): No edge data
# 251107-03:53:17,477 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.meanfunc3): new edge data: {'connect': [(('out_file', 'def pickrun(files, whichrun):\n    """pick file from list of files"""\n\n    filemap = {\'first\': 0, \'last\': -1, \'middle\': len(files) // 2}\n\n    if isinstance(files, list):\n\n        # whichrun is given as integer\n        if isinstance(whichrun, int):\n            return files[whichrun]\n        # whichrun is given as string\n        elif isinstance(whichrun, str):\n            if whichrun not in filemap.keys():\n                raise (KeyError, \'Sorry, whichrun must be either integer index\'\n                       \'or string in form of "first", "last" or "middle\')\n            else:\n                return files[filemap[whichrun]]\n    else:\n        # in case single file name is given\n        return files\n', (0,)), 'in_file')]}
# 251107-03:53:17,478 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc3, featpreproc.outputspec): No edge data
# 251107-03:53:17,479 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc3, featpreproc.outputspec): new edge data: {'connect': [('out_file', 'mean')]}
# 251107-03:53:22,671 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:22,675 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:53:22,677 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.highpass): No edge data
# 251107-03:53:22,679 nipype.workflow DEBUG:
# 	 (featpreproc.inputspec, featpreproc.highpass): new edge data: {'connect': [(('highpass', "highpass_operand = lambda x: '-bptf %.10f -1' % x\n", ()), 'op_string')]}
# 251107-03:53:22,688 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.highpass): No edge data
# 251107-03:53:22,690 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.highpass): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:53:27,846 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:27,850 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:53:27,851 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.meanfunc4): No edge data
# 251107-03:53:27,853 nipype.workflow DEBUG:
# 	 (featpreproc.meanscale, featpreproc.meanfunc4): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:53:33,55 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:33,59 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 251107-03:53:33,60 nipype.workflow DEBUG:
# 	 adding multipath trait: operand_file
# 251107-03:53:33,62 nipype.workflow DEBUG:
# 	 (featpreproc.highpass, featpreproc.addmean): No edge data
# 251107-03:53:33,67 nipype.workflow DEBUG:
# 	 (featpreproc.highpass, featpreproc.addmean): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:53:33,69 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc4, featpreproc.addmean): No edge data
# 251107-03:53:33,69 nipype.workflow DEBUG:
# 	 (featpreproc.meanfunc4, featpreproc.addmean): new edge data: {'connect': [('out_file', 'operand_file')]}
# 251107-03:53:33,71 nipype.workflow DEBUG:
# 	 (featpreproc.addmean, featpreproc.outputspec): No edge data
# 251107-03:53:33,72 nipype.workflow DEBUG:
# 	 (featpreproc.addmean, featpreproc.outputspec): new edge data: {'connect': [('out_file', 'highpassed_files')]}
# 251107-03:53:33,85 nipype.workflow DEBUG:
# 	 [Node] inputspec - setting input highpass = 100
# 251107-03:53:38,245 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-03:53:38,251 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, preprocess_fsl.selectfiles_preproc): No edge data
# 251107-03:53:38,253 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, preprocess_fsl.selectfiles_preproc): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task')]}
# 251107-03:53:38,254 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.img2float): No edge data
# 251107-03:53:38,255 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.img2float): new edge data: {'connect': [('func', 'in_file')]}
# 251107-03:53:38,257 nipype.workflow DEBUG:
# 	 (preprocess_fsl.img2float, preprocess_fsl.extract_first): No edge data
# 251107-03:53:38,258 nipype.workflow DEBUG:
# 	 (preprocess_fsl.img2float, preprocess_fsl.extract_first): new edge data: {'connect': [('out_file', 'in_file')]}
# 251107-03:53:38,260 nipype.workflow DEBUG:
# 	 (preprocess_fsl.extract_first, preprocess_fsl.registration): No edge data
# 251107-03:53:38,261 nipype.workflow DEBUG:
# 	 (preprocess_fsl.extract_first, preprocess_fsl.registration): new edge data: {'connect': [('roi_file', 'inputspec.mean_image')]}
# 251107-03:53:38,263 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.registration): No edge data
# 251107-03:53:38,263 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.registration): new edge data: {'connect': [('func', 'inputspec.source_files'), ('anat', 'inputspec.anatomical_image')]}
# 251107-03:53:38,264 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, preprocess_fsl.featpreproc): No edge data
# 251107-03:53:38,265 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, preprocess_fsl.featpreproc): new edge data: {'connect': [('fwhm', 'inputspec.fwhm')]}
# 251107-03:53:38,266 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.featpreproc): No edge data
# 251107-03:53:38,267 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, preprocess_fsl.featpreproc): new edge data: {'connect': [('func', 'inputspec.func')]}
# 251107-03:53:38,267 nipype.workflow DEBUG:
# 	 (preprocess_fsl.registration, preprocess_fsl.datasink): No edge data
# 251107-03:53:38,269 nipype.workflow DEBUG:
# 	 (preprocess_fsl.registration, preprocess_fsl.datasink): new edge data: {'connect': [('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all'), ('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')]}
# 251107-03:53:38,269 nipype.workflow DEBUG:
# 	 (preprocess_fsl.featpreproc, preprocess_fsl.datasink): No edge data
# 251107-03:53:38,270 nipype.workflow DEBUG:
# 	 (preprocess_fsl.featpreproc, preprocess_fsl.datasink): new edge data: {'connect': [('outputspec.motion_parameters', 'preprocess_fsl.@parameters_file'), ('outputspec.highpassed_files', 'preprocess_fsl.@hp'), ('outputspec.smoothed_files', 'preprocess_fsl.@smooth'), ('outputspec.mask', 'preprocess_fsl.@mask')]}
# 251107-03:53:38,291 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preprocess_fsl
# 251107-03:53:38,302 nipype.workflow DEBUG:
# 	 expanding workflow: preprocess_fsl
# 251107-03:53:38,302 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.infosource_preproc
# 251107-03:53:38,304 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.selectfiles_preproc
# 251107-03:53:38,305 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.img2float
# 251107-03:53:38,307 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.extract_first
# 251107-03:53:38,307 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.registration
# 251107-03:53:38,308 nipype.workflow DEBUG:
# 	 in: connections-> [('roi_file', 'inputspec.mean_image')]
# 251107-03:53:38,308 nipype.workflow DEBUG:
# 	 in: ('roi_file', 'inputspec.mean_image')
# 251107-03:53:38,309 nipype.workflow DEBUG:
# 	 in edges: preprocess_fsl.extract_first roi_file registration.inputspec mean_image
# 251107-03:53:38,309 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.extract_first->preprocess_fsl.registration [('roi_file', 'inputspec.mean_image')]
# 251107-03:53:38,309 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('roi_file', 'inputspec.mean_image')]
# 251107-03:53:38,310 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('roi_file', 'inputspec.mean_image')
# 251107-03:53:38,310 nipype.workflow DEBUG:
# 	 (preprocess_fsl.extract_first, registration.inputspec): No edge data
# 251107-03:53:38,310 nipype.workflow DEBUG:
# 	 (preprocess_fsl.extract_first, registration.inputspec): new edge data: {'connect': [('roi_file', 'mean_image')]}
# 251107-03:53:38,311 nipype.workflow DEBUG:
# 	 in: connections-> [('func', 'inputspec.source_files'), ('anat', 'inputspec.anatomical_image')]
# 251107-03:53:38,311 nipype.workflow DEBUG:
# 	 in: ('func', 'inputspec.source_files')
# 251107-03:53:38,312 nipype.workflow DEBUG:
# 	 in edges: preprocess_fsl.selectfiles_preproc func registration.inputspec source_files
# 251107-03:53:38,312 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.selectfiles_preproc->preprocess_fsl.registration [('func', 'inputspec.source_files')]
# 251107-03:53:38,312 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('func', 'inputspec.source_files')]
# 251107-03:53:38,313 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('func', 'inputspec.source_files')
# 251107-03:53:38,313 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, registration.inputspec): No edge data
# 251107-03:53:38,313 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, registration.inputspec): new edge data: {'connect': [('func', 'source_files')]}
# 251107-03:53:38,313 nipype.workflow DEBUG:
# 	 in: ('anat', 'inputspec.anatomical_image')
# 251107-03:53:38,316 nipype.workflow DEBUG:
# 	 in edges: preprocess_fsl.selectfiles_preproc anat registration.inputspec anatomical_image
# 251107-03:53:38,316 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.selectfiles_preproc->preprocess_fsl.registration [('anat', 'inputspec.anatomical_image')]
# 251107-03:53:38,316 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('anat', 'inputspec.anatomical_image')]
# 251107-03:53:38,317 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('anat', 'inputspec.anatomical_image')
# 251107-03:53:38,317 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, registration.inputspec): Edge data exists: {'connect': [('func', 'source_files')]}
# 251107-03:53:38,318 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, registration.inputspec): new edge data: {'connect': [('func', 'source_files'), ('anat', 'anatomical_image')]}
# 251107-03:53:38,318 nipype.workflow DEBUG:
# 	 out: connections-> [('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all'), ('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')]
# 251107-03:53:38,318 nipype.workflow DEBUG:
# 	 out: ('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all')
# 251107-03:53:38,319 nipype.workflow DEBUG:
# 	 out edges: registration.outputspec anat2target_transform preprocess_fsl.datasink preprocess_fsl.@transfo_all
# 251107-03:53:38,319 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.registration->preprocess_fsl.datasink [('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all')]
# 251107-03:53:38,319 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all')]
# 251107-03:53:38,320 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('outputspec.anat2target_transform', 'preprocess_fsl.@transfo_all')
# 251107-03:53:38,321 nipype.workflow DEBUG:
# 	 (registration.outputspec, preprocess_fsl.datasink): No edge data
# 251107-03:53:38,321 nipype.workflow DEBUG:
# 	 (registration.outputspec, preprocess_fsl.datasink): new edge data: {'connect': [('anat2target_transform', 'preprocess_fsl.@transfo_all')]}
# 251107-03:53:38,321 nipype.workflow DEBUG:
# 	 out: ('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')
# 251107-03:53:38,322 nipype.workflow DEBUG:
# 	 out edges: registration.outputspec func2anat_transform preprocess_fsl.datasink preprocess_fsl.@transfo_init
# 251107-03:53:38,322 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.registration->preprocess_fsl.datasink [('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')]
# 251107-03:53:38,322 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')]
# 251107-03:53:38,323 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('outputspec.func2anat_transform', 'preprocess_fsl.@transfo_init')
# 251107-03:53:38,323 nipype.workflow DEBUG:
# 	 (registration.outputspec, preprocess_fsl.datasink): Edge data exists: {'connect': [('anat2target_transform', 'preprocess_fsl.@transfo_all')]}
# 251107-03:53:38,323 nipype.workflow DEBUG:
# 	 (registration.outputspec, preprocess_fsl.datasink): new edge data: {'connect': [('anat2target_transform', 'preprocess_fsl.@transfo_all'), ('func2anat_transform', 'preprocess_fsl.@transfo_init')]}
# 251107-03:53:38,324 nipype.workflow DEBUG:
# 	 expanding workflow: preprocess_fsl.registration
# 251107-03:53:38,324 nipype.workflow DEBUG:
# 	 processing node: registration.inputspec
# 251107-03:53:38,325 nipype.workflow DEBUG:
# 	 processing node: registration.stripper
# 251107-03:53:38,325 nipype.workflow DEBUG:
# 	 processing node: registration.fast
# 251107-03:53:38,325 nipype.workflow DEBUG:
# 	 processing node: registration.binarize
# 251107-03:53:38,325 nipype.workflow DEBUG:
# 	 processing node: registration.mean2anat
# 251107-03:53:38,326 nipype.workflow DEBUG:
# 	 processing node: registration.mean2anatbbr
# 251107-03:53:38,326 nipype.workflow DEBUG:
# 	 processing node: registration.anat2target_linear
# 251107-03:53:38,326 nipype.workflow DEBUG:
# 	 processing node: registration.anat2target_nonlinear
# 251107-03:53:38,327 nipype.workflow DEBUG:
# 	 processing node: registration.warpmean
# 251107-03:53:38,327 nipype.workflow DEBUG:
# 	 processing node: registration.warpall
# 251107-03:53:38,327 nipype.workflow DEBUG:
# 	 processing node: registration.outputspec
# 251107-03:53:38,327 nipype.workflow DEBUG:
# 	 finished expanding workflow: preprocess_fsl.registration
# 251107-03:53:38,328 nipype.workflow DEBUG:
# 	 processing node: preprocess_fsl.featpreproc
# 251107-03:53:38,328 nipype.workflow DEBUG:
# 	 in: connections-> [('fwhm', 'inputspec.fwhm')]
# 251107-03:53:38,328 nipype.workflow DEBUG:
# 	 in: ('fwhm', 'inputspec.fwhm')
# 251107-03:53:38,329 nipype.workflow DEBUG:
# 	 in edges: preprocess_fsl.infosource_preproc fwhm featpreproc.inputspec fwhm
# 251107-03:53:38,329 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.infosource_preproc->preprocess_fsl.featpreproc [('fwhm', 'inputspec.fwhm')]
# 251107-03:53:38,330 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('fwhm', 'inputspec.fwhm')]
# 251107-03:53:38,331 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('fwhm', 'inputspec.fwhm')
# 251107-03:53:38,331 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, featpreproc.inputspec): No edge data
# 251107-03:53:38,331 nipype.workflow DEBUG:
# 	 (preprocess_fsl.infosource_preproc, featpreproc.inputspec): new edge data: {'connect': [('fwhm', 'fwhm')]}
# 251107-03:53:38,331 nipype.workflow DEBUG:
# 	 in: connections-> [('func', 'inputspec.func')]
# 251107-03:53:38,332 nipype.workflow DEBUG:
# 	 in: ('func', 'inputspec.func')
# 251107-03:53:38,334 nipype.workflow DEBUG:
# 	 in edges: preprocess_fsl.selectfiles_preproc func featpreproc.inputspec func
# 251107-03:53:38,335 nipype.workflow DEBUG:
# 	 disconnect(): preprocess_fsl.selectfiles_preproc->preprocess_fsl.featpreproc [('func', 'inputspec.func')]
# 251107-03:53:38,335 nipype.workflow DEBUG:
# 	 disconnect(): remove list [('func', 'inputspec.func')]
# 251107-03:53:38,335 nipype.workflow DEBUG:
# 	 disconnect(): removed connection ('func', 'inputspec.func')
# 251107-03:53:38,336 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, featpreproc.inputspec): No edge data
# 251107-03:53:38,336 nipype.workflow DEBUG:
# 	 (preprocess_fsl.selectfiles_preproc, featpreproc.inputspec): new edge data: {'connect': [('func', 'func')]}
# 251107-03:53:38,336 nipype.workflow DEBUG:
# 	 out: connections-> [('outputspec.motion_parameters', 'preprocess_fsl.@parameters_file'), ('outputspec.highpassed_files', 'preprocess_fsl.@hp'), ('outputspec.smoothed_files', 'preprocess_fsl.@smooth'), ('outputspec.mask', 'preprocess_fsl.@mask')]
# 251107-03:53:38,337 nipype.workflow DEBUG:
# ...
# 251107-04:43:28,3 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat
# 251107-04:43:28,3 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/mean2anatbbr/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat
# 251107-04:43:28,4 nipype.interface DEBUG:
# 	 key: preprocess_fsl.@transfo_all files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/anat2target_nonlinear/131823_3T_T1w_MPR1_fieldwarp.nii.gz
# 251107-04:43:28,5 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/anat2target_nonlinear/131823_3T_T1w_MPR1_fieldwarp.nii.gz /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz
# 251107-04:43:28,5 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz
# 251107-04:43:28,6 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/anat2target_nonlinear/131823_3T_T1w_MPR1_fieldwarp.nii.gz
# 251107-04:43:28,7 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz
# 251107-04:43:28,7 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz already exists, not overwriting, copy:1
# 251107-04:43:28,8 nipype.interface DEBUG:
# 	 key: preprocess_fsl.@parameters_file files: ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/realign/mapflow/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par']
# 251107-04:43:28,8 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/realign/mapflow/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par
# 251107-04:43:28,9 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par
# 251107-04:43:28,9 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/realign/mapflow/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par
# 251107-04:43:28,11 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par
# 251107-04:43:28,11 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par already exists, not overwriting, copy:1
# 251107-04:43:28,12 nipype.interface DEBUG:
# 	 key: preprocess_fsl.@mask files: ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/dilatemask/mapflow/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz']
# 251107-04:43:28,12 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/dilatemask/mapflow/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz
# 251107-04:43:28,13 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz
# 251107-04:43:28,13 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/dilatemask/mapflow/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz
# 251107-04:43:28,14 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz
# 251107-04:43:28,15 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz already exists, not overwriting, copy:1
# 251107-04:43:28,15 nipype.interface DEBUG:
# 	 key: preprocess_fsl.@smooth files: ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/maskfunc3/mapflow/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz']
# 251107-04:43:28,16 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/maskfunc3/mapflow/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz
# 251107-04:43:28,16 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz
# 251107-04:43:28,16 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/maskfunc3/mapflow/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz
# 251107-04:43:28,17 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz
# 251107-04:43:28,18 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz already exists, not overwriting, copy:1
# 251107-04:43:28,18 nipype.interface DEBUG:
# 	 key: preprocess_fsl.@hp files: ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/addmean/mapflow/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz']
# 251107-04:43:28,19 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/addmean/mapflow/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:43:28,19 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:43:28,20 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/addmean/mapflow/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:43:28,21 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:43:28,21 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz already exists, not overwriting, copy:1
# 251107-04:43:28,22 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.019959s.
# 251107-04:43:28,25 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/131823_3T_T1w_MPR1_fieldwarp.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/addmean/mapflow/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/dilatemask/mapflow/_dilatemask0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_bet_thresh_dil.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/realign/mapflow/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/featpreproc/_fwhm_8_subject_id_131823_task_GAMBLING/maskfunc3/mapflow/_maskfunc30/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/anat2target_nonlinear/131823_3T_T1w_MPR1_fieldwarp.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/mean2anatbbr/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/mean2anatbbr/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/mean2anatbbr/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_task_GAMBLING/mean2anatbbr/131823_3T_tfMRI_GAMBLING_LR_dtype_roi_flirt.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/registration/_fwhm_8_subject_id_131823_t ...
# 251107-04:43:28,25 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-04:43:28,26 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:43:28,26 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-04:43:28,28 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"

# %%
#works for specifying fwhm, nb_param, hrf
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [5], 
                                                     [0], ['derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-04:49:11,294 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:16,483 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:21,664 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:26,869 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:32,50 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# Use derivatives
# 251107-04:49:37,224 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:42,405 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:47,580 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:49:47,586 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-04:49:47,587 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-04:49:47,588 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-04:49:47,589 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-04:49:47,590 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-04:49:47,590 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-04:49:47,592 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-04:49:47,593 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-04:49:47,594 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-04:49:47,595 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-04:49:47,597 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-04:49:47,598 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-04:49:47,598 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:49:47,599 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-04:49:47,600 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:49:47,600 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-04:49:47,601 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-04:49:47,601 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-04:49:47,602 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-04:49:47,602 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-04:49:47,607 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-04:49:47,611 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-04:49:47,619 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-04:49:47,627 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-04:49:47,632 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-04:49:47,633 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-04:49:47,634 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-04:49:47,634 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-04:49:47,635 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-04:49:47,636 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-04:49:47,636 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-04:49:47,637 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-04:49:47,639 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-04:49:47,642 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-04:49:47,643 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-04:49:47,644 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-04:49:47,646 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089d30>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089550>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089af0>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089a60>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089e50>}
# 251107-04:49:47,647 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-04:49:47,657 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:49:47,658 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:49:47,659 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:49:47,659 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:49:47,659 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:49:47,659 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:49:47,661 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-04:49:47,663 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:49:47,664 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:49:47,665 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:49:47,665 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:49:47,669 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-04:49:47,677 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-04:49:47,686 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 0/0/1 (done/running/ready), 0/7 (pending_tasks/waiting).
# 251107-04:49:47,687 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:47,687 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:49:47,791 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:47,795 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:49:47,795 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:49:47,797 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:49:47,868 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-04:49:47,872 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:49:47,880 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:49:47,880 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:49:47,881 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:49:47,882 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:49:47,887 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:49:47,890 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:49:47,895 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003029s.
# 251107-04:49:47,897 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:49:47,898 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:49:47,899 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:49:47,899 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:49:47,901 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:49:49,694 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 0/1/0 (done/running/ready), 1/6 (pending_tasks/waiting).
# 251107-04:49:49,696 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:49:49,703 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:49,705 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:49:49,777 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=1 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:49,778 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:49:49,779 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:49:49,780 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:49,780 nipype.workflow DEBUG:
# 	 output: event
# 251107-04:49:49,781 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-04:49:49,785 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-04:49:49,785 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-04:49:49,785 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-04:49:49,786 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 1.
# 251107-04:49:49,787 nipype.workflow INFO:
# 	 [Job 1] Cached (l1_analysis_fsl.subject_infos).
# 251107-04:49:51,694 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 2/0/1 (done/running/ready), 0/5 (pending_tasks/waiting).
# 251107-04:49:51,695 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:51,730 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.specify_model ID=2 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:51,732 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "specify_model" from 2 previous nodes.
# 251107-04:49:51,733 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:49:51,734 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:51,734 nipype.workflow DEBUG:
# 	 output: func
# 251107-04:49:51,734 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input functional_runs = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:49:51,735 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/result_subject_infos.pklz
# 251107-04:49:51,736 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:51,736 nipype.workflow DEBUG:
# 	 output: subject_info
# 251107-04:49:51,737 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input subject_info = Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)
# 251107-04:49:51,738 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bids_condition_column', 'trial_type'), ('functional_runs', [('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '32347046a9f0f071f6e01f3e45133d96')]), ('high_pass_filter_cutoff', '60.0000000000'), ('input_units', 'secs'), ('parameter_source', 'SPM'), ('subject_info', [Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)]), ('time_repetition', '0.7200000000')], 03b3e10f0f09d5297a26b9fb93b80867, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/_0x03b3e10f0f09d5297a26b9fb93b80867.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/_0x03b3e10f0f09d5297a26b9fb93b80867.json']
# 251107-04:49:51,738 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.specify_model".
# 251107-04:49:51,739 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.specify_model" locally: cached=True, updated=True.
# 251107-04:49:51,739 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.specify_model with ID 2.
# 251107-04:49:51,739 nipype.workflow INFO:
# 	 [Job 2] Cached (l1_analysis_fsl.specify_model).
# 251107-04:49:53,704 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 3/0/1 (done/running/ready), 0/4 (pending_tasks/waiting).
# 251107-04:49:53,707 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:53,766 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.l1_design ID=3 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:53,768 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "l1_design" from 1 previous nodes.
# 251107-04:49:53,769 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/result_specify_model.pklz
# 251107-04:49:53,770 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:53,770 nipype.workflow DEBUG:
# 	 output: session_info
# 251107-04:49:53,774 nipype.workflow DEBUG:
# 	 [Node] l1_design - setting input session_info = [{'cond': [{'name': 'loss', 'onset': [8.063, 95.855], 'duration': [28.0, 28.0]}, {'name': 'loss_event', 'onset': [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}, {'name': 'neut_event', 'onset': [55.577, 73.65], 'duration': [3.5, 3.5]}, {'name': 'win', 'onset': [51.965, 139.704], 'duration': [28.0, 28.0]}, {'name': 'win_event', 'onset': [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}], 'hpf': 60.0, 'regress': [], 'scans': '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz'}]
# 251107-04:49:53,777 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bases', [('dgamma', [('derivs', True)])]), ('contrasts', [('loss vs baseline', 'T', ['loss'], ['1.0000000000']), ('loss_event vs baseline', 'T', ['loss_event'], ['1.0000000000']), ('neut_event vs baseline', 'T', ['neut_event'], ['1.0000000000']), ('win vs baseline', 'T', ['win'], ['1.0000000000']), ('win_event vs baseline', 'T', ['win_event'], ['1.0000000000'])]), ('interscan_interval', '0.7200000000'), ('model_serial_correlations', True), ('orthogonalization', []), ('session_info', [[('cond', [[('duration', ['28.0000000000', '28.0000000000']), ('name', 'loss'), ('onset', ['8.0630000000', '95.8550000000'])], [('duration', ['3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000']), ('name', 'loss_event'), ('onset', ['8.0630000000', '11.6880000000', '18.8990000000', '26.1360000000', '29.7480000000', '33.3600000000', '95.8550000000', '99.4660000000', '106.6640000000', '113.8740000000', '117.4860000000', '121.0980000000', '146.9280000000', '154.1650000000'])], [('duration', ['3.5000000000', '3.5000000000']), ('name', 'neut_event'), ('onset', ['55.5770000000', '73.6500000000'])], [('duration', ['28.0000000000', '28.0000000000']), ('name', 'win'), ('onset', ['51.9650000000', '139.7040000000'])], [('duration', ['3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000']), ('name', 'win_event'), ('onset', ['15.3000000000', '22.5110000000', '51.9650000000', '59.1890000000', '62.8010000000', '66.4260000000', '70.0380000000', '77.2490000000', '103.0650000000', '110.2620000000', '139.7040000000', '143.3160000000', '150.5530000000', '157.7760000000', '161.4020000000', '165.0000000000'])]]), ('hpf', '60.0000000000'), ('regress', []), ('scans', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '32347046a9f0f071f6e01f3e45133d96'))]])], 705378ae3f8f56b59d9e90da4cd43809, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/_0x705378ae3f8f56b59d9e90da4cd43809.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/_0x705378ae3f8f56b59d9e90da4cd43809.json']
# 251107-04:49:53,778 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.l1_design".
# 251107-04:49:53,778 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.l1_design" locally: cached=True, updated=True.
# 251107-04:49:53,778 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.l1_design with ID 3.
# 251107-04:49:53,781 nipype.workflow INFO:
# 	 [Job 3] Cached (l1_analysis_fsl.l1_design).
# 251107-04:49:55,708 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 4/0/1 (done/running/ready), 0/3 (pending_tasks/waiting).
# 251107-04:49:55,711 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:55,771 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.model_generation ID=4 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:55,773 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "model_generation" from 1 previous nodes.
# 251107-04:49:55,773 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/result_l1_design.pklz
# 251107-04:49:55,775 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:55,776 nipype.workflow DEBUG:
# 	 output: ev_files
# 251107-04:49:55,776 nipype.workflow DEBUG:
# 	 [Node] model_generation - setting input ev_files = ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_loss_0_1.txt', '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_loss_event_0_3.txt', '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_neut_event_0_5.txt', '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_win_0_7.txt', '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_win_event_0_9.txt']
# 251107-04:49:55,777 nipype.workflow DEBUG:
# 	 output: fsf_files
# 251107-04:49:55,777 nipype.workflow DEBUG:
# 	 [Node] model_generation - setting input fsf_file = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/run0.fsf
# 251107-04:49:55,778 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('ev_files', [('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_loss_0_1.txt', '5f72c1237f8a3d420add465e58213bdd'), ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_loss_event_0_3.txt', '80e5a87bbb9f8d6d63b564676e738d99'), ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_neut_event_0_5.txt', 'c3ef29e7f8ed5328590e5fcb72aa8a36'), ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_win_0_7.txt', 'c10b267ccf80c42a07e5f6048839d3fb'), ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/ev_win_event_0_9.txt', '6fc24ebcc3cce8ad798cdaca838ed2a3')]), ('fsf_file', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/l1_design/run0.fsf', '70afe8bff7c3a5871222dab0550a5e44')), ('output_type', 'NIFTI_GZ')], f55d73f9db0d177af0b6e7fe9c8a36ce, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/_0xf55d73f9db0d177af0b6e7fe9c8a36ce.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/_0xf55d73f9db0d177af0b6e7fe9c8a36ce.json']
# 251107-04:49:55,778 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.model_generation".
# 251107-04:49:55,779 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.model_generation" locally: cached=True, updated=True.
# 251107-04:49:55,779 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.model_generation with ID 4.
# 251107-04:49:55,779 nipype.workflow INFO:
# 	 [Job 4] Cached (l1_analysis_fsl.model_generation).
# 251107-04:49:57,711 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 5/0/1 (done/running/ready), 0/2 (pending_tasks/waiting).
# 251107-04:49:57,713 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:57,780 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.model_estimate ID=5 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:57,781 nipype.workflow DEBUG:
# 	 [Node] Setting 3 connected inputs of node "model_estimate" from 2 previous nodes.
# 251107-04:49:57,782 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:49:57,783 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:57,783 nipype.workflow DEBUG:
# 	 output: func
# 251107-04:49:57,783 nipype.workflow DEBUG:
# 	 [Node] model_estimate - setting input in_file = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:49:57,784 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/result_model_generation.pklz
# 251107-04:49:57,786 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:57,787 nipype.workflow DEBUG:
# 	 output: con_file
# 251107-04:49:57,787 nipype.workflow DEBUG:
# 	 [Node] model_estimate - setting input tcon_file = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.con
# 251107-04:49:57,787 nipype.workflow DEBUG:
# 	 output: design_file
# 251107-04:49:57,787 nipype.workflow DEBUG:
# 	 [Node] model_estimate - setting input design_file = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat
# 251107-04:49:57,788 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('autocorr_noestimate', True), ('design_file', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat', 'ca0e6de2134288d8108d5e6665000ba3')), ('full_data', False), ('in_file', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '32347046a9f0f071f6e01f3e45133d96')), ('output_type', 'NIFTI_GZ'), ('results_dir', 'results'), ('tcon_file', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.con', '41971b69238fbfb2fbfc693ca9ca2de5')), ('threshold', '-1000.0000000000')], d53b5e194a0f7533d02d880b913bbc4d, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_0xd53b5e194a0f7533d02d880b913bbc4d.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_0xd53b5e194a0f7533d02d880b913bbc4d.json']
# 251107-04:49:57,789 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.model_estimate".
# 251107-04:49:57,789 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.model_estimate" locally: cached=True, updated=True.
# 251107-04:49:57,789 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.model_estimate with ID 5.
# 251107-04:49:57,789 nipype.workflow INFO:
# 	 [Job 5] Cached (l1_analysis_fsl.model_estimate).
# 251107-04:49:59,714 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 6/0/1 (done/running/ready), 0/1 (pending_tasks/waiting).
# 251107-04:49:59,716 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:49:59,783 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.datasink ID=6 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:49:59,784 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink".
# 251107-04:49:59,784 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.datasink" locally: cached=False, updated=False.
# 251107-04:49:59,785 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.datasink (taskid=2).
# 251107-04:49:59,788 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.datasink" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink".
# 251107-04:49:59,791 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink".
# 251107-04:49:59,791 nipype.workflow DEBUG:
# 	 [Node] Setting 3 connected inputs of node "datasink" from 2 previous nodes.
# 251107-04:49:59,792 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/result_model_generation.pklz
# 251107-04:49:59,794 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:59,795 nipype.workflow DEBUG:
# 	 output: design_file
# 251107-04:49:59,795 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input l1_analysis_fsl.@design_file = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat
# 251107-04:49:59,796 nipype.workflow DEBUG:
# 	 output: design_image
# 251107-04:49:59,797 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input l1_analysis_fsl.@design_img = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.png
# 251107-04:49:59,798 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz
# 251107-04:49:59,800 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:49:59,801 nipype.workflow DEBUG:
# 	 output: results_dir
# 251107-04:49:59,802 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input l1_analysis_fsl.@results = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results
# 251107-04:49:59,803 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink
# 251107-04:49:59,804 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-04:49:59,807 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 251107-04:49:59,808 nipype.interface DEBUG:
# 	 key: l1_analysis_fsl.@design_file files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat
# 251107-04:49:59,809 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.mat
# 251107-04:49:59,810 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.mat
# 251107-04:49:59,810 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.mat->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat
# 251107-04:49:59,811 nipype.interface DEBUG:
# 	 key: l1_analysis_fsl.@design_img files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.png
# 251107-04:49:59,812 nipype.interface DEBUG:
# 	 copyfile: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.png /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png
# 251107-04:49:59,813 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png
# 251107-04:49:59,813 nipype.utils DEBUG:
# 	 Linking File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.png
# 251107-04:49:59,814 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png
# 251107-04:49:59,815 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png already exists, not overwriting, copy:1
# 251107-04:49:59,816 nipype.interface DEBUG:
# 	 key: l1_analysis_fsl.@results files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results
# 251107-04:49:59,816 nipype.interface DEBUG:
# 	 copydir: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/ /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results
# 251107-04:49:59,818 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/threshac1.nii.gz
# 251107-04:49:59,818 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/threshac1.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz
# 251107-04:49:59,819 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/threshac1.nii.gz
# 251107-04:49:59,820 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/threshac1.nii.gz already exists,06e7a0ad98ba2f2380ec37348caa0a6c, copy:1
# 251107-04:49:59,821 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/threshac1.nii.gz already exists, not overwriting, copy:1
# 251107-04:49:59,822 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope3.nii.gz
# 251107-04:49:59,822 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope3.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz
# ...
# 251107-04:50:01,48 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,48 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-04:50:01,49 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz
# 251107-04:50:01,52 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-04:50:01,55 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists,781762b84889e1a40b13780737ef1f4b, copy:1
# 251107-04:50:01,57 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,58 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-04:50:01,59 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz
# 251107-04:50:01,62 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-04:50:01,64 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists,0dfa7efa0255db1d1ed9f71906ca77b3, copy:1
# 251107-04:50:01,66 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,67 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe8.nii.gz
# 251107-04:50:01,68 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe8.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe8.nii.gz
# 251107-04:50:01,70 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe8.nii.gz
# 251107-04:50:01,73 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe8.nii.gz already exists,dae07cb5da0d0114d3a53dcf4826d8fd, copy:1
# 251107-04:50:01,75 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe8.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,76 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-04:50:01,76 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/zstat3.nii.gz
# 251107-04:50:01,79 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-04:50:01,81 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists,760f892142dc3ab8f14d1ad7f809d83d, copy:1
# 251107-04:50:01,83 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,84 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-04:50:01,84 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/zstat1.nii.gz
# 251107-04:50:01,86 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-04:50:01,89 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists,0052d1713efd77bb1455a88eb92b7e45, copy:1
# 251107-04:50:01,91 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,92 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-04:50:01,92 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz
# 251107-04:50:01,95 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-04:50:01,97 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists,e33df794d737d13cb39a5ab639ebcb9f, copy:1
# 251107-04:50:01,99 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,100 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:50:01,100 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe6.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe6.nii.gz
# 251107-04:50:01,102 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:50:01,105 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists,0e4eb4df54d335f7c7d763f8336b0f39, copy:1
# 251107-04:50:01,107 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,107 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:50:01,108 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/tstat4.nii.gz
# 251107-04:50:01,110 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:50:01,113 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,20acd36b073cb526a28e1bdd049b2bdd, copy:1
# 251107-04:50:01,115 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-04:50:01,116 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 1.307792s.
# 251107-04:50:01,117 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_generation/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_0x53e4b3038a7868ffa8dc886f2a339ac9_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_node.pklz
# 251107-04:50:01,118 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-04:50:01,119 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:50:01,119 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-04:50:01,121 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-04:50:01,720 nipype.workflow DEBUG:
# 	 Progress: 7 jobs, 6/1/0 (done/running/ready), 1/0 (pending_tasks/waiting).
# 251107-04:50:01,720 nipype.workflow INFO:
# 	 [Job 6] Completed (l1_analysis_fsl.datasink).
# 251107-04:50:01,721 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:50:01,722 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:50:01,723 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock

# %%
#worked
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [8], 
                                                     nb_param, ['derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-04:52:22,805 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:27,979 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:33,160 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:38,346 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:43,524 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# Use derivatives
# 251107-04:52:48,701 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:53,872 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:59,75 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:52:59,80 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-04:52:59,81 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-04:52:59,82 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-04:52:59,83 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-04:52:59,84 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-04:52:59,85 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-04:52:59,88 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-04:52:59,90 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-04:52:59,91 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-04:52:59,93 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-04:52:59,95 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-04:52:59,96 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-04:52:59,96 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:52:59,97 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-04:52:59,98 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:52:59,99 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-04:52:59,100 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-04:52:59,103 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-04:52:59,106 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-04:52:59,108 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-04:52:59,110 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-04:52:59,115 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-04:52:59,123 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-04:52:59,125 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-04:52:59,126 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-04:52:59,127 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-04:52:59,128 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-04:52:59,129 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-04:52:59,130 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-04:52:59,131 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-04:52:59,131 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-04:52:59,132 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-04:52:59,133 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-04:52:59,141 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-04:52:59,143 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-04:52:59,145 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-04:52:59,146 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089c10>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089790>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089940>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00894c0>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe0089700>}
# 251107-04:52:59,147 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-04:52:59,156 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:52:59,157 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:52:59,159 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:52:59,160 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:52:59,160 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:52:59,160 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:52:59,163 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:52:59,163 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:52:59,164 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-04:52:59,164 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:52:59,164 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:52:59,165 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-04:52:59,172 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:52:59,173 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:52:59,174 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-04:52:59,175 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:52:59,176 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:52:59,176 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-04:52:59,177 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-04:52:59,177 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:52:59,178 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:52:59,178 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:52:59,178 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:52:59,179 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:52:59,179 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:52:59,179 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:52:59,180 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:52:59,180 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:52:59,180 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:52:59,181 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:52:59,181 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:52:59,191 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-04:52:59,194 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-04:52:59,196 nipype.workflow DEBUG:
# 	 Progress: 21 jobs, 0/0/3 (done/running/ready), 0/21 (pending_tasks/waiting).
# 251107-04:52:59,198 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:52:59,198 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:52:59,235 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:52:59,237 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,238 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,238 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:52:59,282 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-04:52:59,283 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-04:52:59,285 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:52:59,287 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,287 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,288 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:52:59,289 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-04:52:59,288 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,289 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=2 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-04:52:59,289 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,290 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:52:59,290 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:52:59,294 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,295 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,294 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,294 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:52:59,295 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:52:59,295 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,297 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=3).
# 251107-04:52:59,296 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:52:59,299 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:52:59,300 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:52:59,302 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:52:59,303 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-04:52:59,304 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:52:59,305 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:52:59,307 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:52:59,308 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:52:59,308 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:52:59,313 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003804s.
# 251107-04:52:59,315 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:52:59,316 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:52:59,320 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001234s.
# 251107-04:52:59,322 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:52:59,323 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:52:59,323 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:52:59,324 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:52:59,326 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:52:59,328 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002105s.
# 251107-04:52:59,329 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:52:59,330 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:52:59,330 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:52:59,331 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:52:59,332 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:52:59,334 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:52:59,334 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:52:59,335 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:52:59,336 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:52:59,336 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:52:59,338 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:53:01,209 nipype.workflow DEBUG:
# 	 Progress: 21 jobs, 0/3/0 (done/running/ready), 3/18 (pending_tasks/waiting).
# 251107-04:53:01,211 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:53:01,214 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:53:01,217 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:53:01,219 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:53:01,222 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:53:01,298 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=3 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:53:01,301 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:53:01,301 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:53:01,302 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:53:01,302 nipype.workflow DEBUG:
# 	 output: event
# 251107-04:53:01,303 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-04:53:01,305 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-04:53:01,305 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-04:53:01,306 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-04:53:01,306 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 3.
# 251107-04:53:01,306 nipype.workflow INFO:
# 	 [Job 3] Cached (l1_analysis_fsl.subject_infos).
# 251107-04:53:01,307 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=4 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-04:53:01,308 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:53:01,309 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:53:01,309 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:53:01,310 nipype.workflow DEBUG:
# 	 output: event
# 251107-04:53:01,310 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-04:53:01,311 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-04:53:01,311 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-04:53:01,312 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-04:53:01,312 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 4.
# 251107-04:53:01,312 nipype.workflow INFO:
# 	 [Job 4] Cached (l1_analysis_fsl.subject_infos).
# 251107-04:53:01,313 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=5 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-04:53:01,314 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:53:01,314 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:53:01,315 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:53:01,315 nipype.workflow DEBUG:
# 	 output: event
# 251107-04:53:01,315 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-04:53:01,317 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-04:53:01,317 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-04:53:01,317 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-04:53:01,318 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 5.
# 251107-04:53:01,318 nipype.workflow INFO:
# 	 [Job 5] Cached (l1_analysis_fsl.subject_infos).
# 251107-04:53:03,214 nipype.workflow DEBUG:
# 	 Progress: 21 jobs, 6/0/3 (done/running/ready), 0/15 (pending_tasks/waiting).
# 251107-04:53:03,217 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:53:03,283 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.specify_model ID=6 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:53:03,285 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "specify_model" from 2 previous nodes.
# 251107-04:53:03,285 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:53:03,286 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:53:03,287 nipype.workflow DEBUG:
# 	 output: func
# 251107-04:53:03,287 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input functional_runs = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-04:53:03,287 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos/result_subject_infos.pklz
# 251107-04:53:03,288 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-04:53:03,289 nipype.workflow DEBUG:
# 	 output: subject_info
# 251107-04:53:03,289 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input subject_info = Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)
# 251107-04:53:03,290 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bids_condition_column', 'trial_type'), ('functional_runs', [('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '21b28def444b22e675a6e9b1da70184f')]), ('high_pass_filter_cutoff', '60.0000000000'), ('input_units', 'secs'), ('parameter_source', 'SPM'), ('subject_info', [Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)]), ('time_repetition', '0.7200000000')], d5730e57cda22a9f06d41eb6386fe86d, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json']
# 251107-04:53:03,291 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.specify_model".
# 251107-04:53:03,291 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.specify_model" locally: cached=True, updated=True.
# 251107-04:53:03,291 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.specify_model with ID 6.
# 251107-04:53:03,291 nipype.workflow INFO:
# ...
# 251107-04:54:09,570 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,570 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,570 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-04:54:09,571 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:54:09,571 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz
# 251107-04:54:09,572 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe6.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe6.nii.gz
# 251107-04:54:09,576 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-04:54:09,576 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:54:09,579 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists,22088fb10e5dd671ddb6f396d0a21112, copy:1
# 251107-04:54:09,580 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists,f9460d86e50a9196782a4c67dde79761, copy:1
# 251107-04:54:09,583 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,584 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,584 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:54:09,585 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:54:09,585 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/pe6.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe6.nii.gz
# 251107-04:54:09,586 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/tstat4.nii.gz
# 251107-04:54:09,590 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/pe6.nii.gz
# 251107-04:54:09,591 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:54:09,596 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists,f9460d86e50a9196782a4c67dde79761, copy:1
# 251107-04:54:09,597 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,72eb08baedaecaa83c53ab566c779028, copy:1
# 251107-04:54:09,601 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/pe6.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,601 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,602 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:54:09,603 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 2.154503s.
# 251107-04:54:09,603 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/tstat4.nii.gz
# 251107-04:54:09,607 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-04:54:09,608 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_0xfc6303fc56acafe3344b626a1aa953d8_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_node.pklz
# 251107-04:54:09,609 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-04:54:09,610 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:54:09,611 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,72eb08baedaecaa83c53ab566c779028, copy:1
# 251107-04:54:09,611 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-04:54:09,614 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-04:54:09,615 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-04:54:09,618 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 2.148209s.
# 251107-04:54:09,620 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_generation/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/_0x55230f6b0eae17f6b42abc7a1fbcc59b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/_node.pklz
# 251107-04:54:09,621 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-04:54:09,622 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:54:09,622 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-04:54:09,624 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-04:54:11,351 nipype.workflow INFO:
# 	 [Job 19] Completed (l1_analysis_fsl.datasink).
# 251107-04:54:11,355 nipype.workflow INFO:
# 	 [Job 20] Completed (l1_analysis_fsl.datasink).
# 251107-04:54:11,357 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:54:11,359 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:54:11,361 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock

# %%
#didn't work
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [5, 8], 
                                                     nb_param, ['no_derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-04:56:11,508 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:16,684 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:21,873 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:27,56 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:32,239 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# No use derivatives
# 251107-04:56:37,414 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:42,603 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:47,777 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:56:47,782 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-04:56:47,785 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-04:56:47,786 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-04:56:47,787 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-04:56:47,787 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-04:56:47,788 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-04:56:47,790 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-04:56:47,793 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-04:56:47,794 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-04:56:47,795 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-04:56:47,796 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-04:56:47,796 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-04:56:47,798 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:56:47,798 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-04:56:47,799 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:56:47,799 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-04:56:47,800 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-04:56:47,800 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-04:56:47,801 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-04:56:47,801 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-04:56:47,803 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-04:56:47,813 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-04:56:47,819 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-04:56:47,819 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-04:56:47,820 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-04:56:47,820 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-04:56:47,821 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-04:56:47,822 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-04:56:47,822 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-04:56:47,823 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-04:56:47,823 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-04:56:47,823 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-04:56:47,825 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-04:56:47,833 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-04:56:47,834 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-04:56:47,835 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-04:56:47,835 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010c8b0>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010cd30>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010cc10>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010c940>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010c1f0>}
# 251107-04:56:47,836 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-04:56:47,839 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:56:47,839 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,840 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:56:47,841 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,842 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,842 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:56:47,845 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:56:47,846 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,847 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-04:56:47,847 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,847 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,848 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-04:56:47,850 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:56:47,851 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,851 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-04:56:47,851 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,852 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,852 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-04:56:47,854 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:56:47,854 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,855 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:56:47,855 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,855 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,855 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:56:47,858 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:56:47,859 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,859 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-04:56:47,860 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,860 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,860 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-04:56:47,862 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-04:56:47,863 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:56:47,863 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-04:56:47,863 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:56:47,863 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:56:47,864 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-04:56:47,864 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-04:56:47,864 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,865 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,865 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:56:47,865 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,865 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,866 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,866 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:56:47,867 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,867 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,868 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,868 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:56:47,868 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,868 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,869 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,869 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:56:47,869 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,869 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,869 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,870 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:56:47,870 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,870 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:56:47,870 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:56:47,871 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-04:56:47,872 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:56:47,882 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-04:56:47,886 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-04:56:47,888 nipype.workflow DEBUG:
# 	 Progress: 42 jobs, 0/0/6 (done/running/ready), 0/42 (pending_tasks/waiting).
# 251107-04:56:47,889 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:56:47,890 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:56:47,930 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:56:47,930 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,931 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:47,984 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-04:56:47,987 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-04:56:47,988 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,989 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:47,988 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,990 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-04:56:47,991 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=2 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-04:56:47,991 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,992 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,993 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:47,994 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=3).
# 251107-04:56:47,992 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,994 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:47,996 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=3 (0.20GB, 1 threads). Free: 6.09GB, 12 threads.
# 251107-04:56:47,996 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,999 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,0 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:47,999 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:47,999 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,0 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=4).
# 251107-04:56:48,1 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=4 (0.20GB, 1 threads). Free: 5.89GB, 11 threads.
# 251107-04:56:48,1 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,1 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:48,1 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:48,3 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,4 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:48,5 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=5).
# 251107-04:56:48,3 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,6 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=5 (0.20GB, 1 threads). Free: 5.69GB, 10 threads.
# 251107-04:56:48,7 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,9 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,9 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,10 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=False, updated=False.
# 251107-04:56:48,8 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,10 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,10 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:48,12 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=6).
# 251107-04:56:48,10 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,15 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,14 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,18 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:56:48,18 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:48,19 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003935s.
# 251107-04:56:48,19 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,20 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,20 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:56:48,24 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,25 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002141s.
# 251107-04:56:48,25 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,27 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,30 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001759s.
# 251107-04:56:48,29 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,32 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,32 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,33 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,35 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,36 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002265s.
# 251107-04:56:48,37 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,38 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,37 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:56:48,39 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003581s.
# 251107-04:56:48,40 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,49 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,52 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,53 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,53 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.009982s.
# 251107-04:56:48,55 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,56 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,57 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,58 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,59 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,62 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,63 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,63 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,63 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,64 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,65 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,65 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:56:48,67 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,67 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:56:48,68 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,68 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,69 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:56:48,70 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:56:48,72 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,72 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:48,73 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:56:49,902 nipype.workflow DEBUG:
# 	 Progress: 42 jobs, 0/6/0 (done/running/ready), 6/36 (pending_tasks/waiting).
# 251107-04:56:49,905 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,908 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,910 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,913 nipype.workflow INFO:
# 	 [Job 3] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,915 nipype.workflow INFO:
# 	 [Job 4] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,916 nipype.workflow INFO:
# 	 [Job 5] Completed (l1_analysis_fsl.selectfiles).
# 251107-04:56:49,917 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:56:49,919 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:56:50,0 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=6 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:56:50,1 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,1 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,2 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=7).
# 251107-04:56:50,2 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=7 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-04:56:50,3 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,3 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,4 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=8).
# 251107-04:56:50,4 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=8 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-04:56:50,5 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,6 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,6 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=9).
# 251107-04:56:50,7 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=9 (0.20GB, 1 threads). Free: 6.09GB, 12 threads.
# 251107-04:56:50,8 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,8 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,8 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=10).
# 251107-04:56:50,9 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=10 (0.20GB, 1 threads). Free: 5.89GB, 11 threads.
# 251107-04:56:50,8 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.subject_infos" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,10 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,10 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,11 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=11).
# 251107-04:56:50,10 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.subject_infos" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,12 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=11 (0.20GB, 1 threads). Free: 5.69GB, 10 threads.
# 251107-04:56:50,12 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,14 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,12 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.subject_infos" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,13 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:56:50,14 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,15 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=False, updated=False.
# 251107-04:56:50,16 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.subject_infos (taskid=12).
# 251107-04:56:50,15 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:56:50,15 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:56:50,16 nipype.workflow DEBUG:
# 	 [Node] Not cached "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos".
# 251107-04:56:50,17 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-04:56:50,17 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-04:56:50,19 nipype.workflow DEBUG:
# ...
# 251107-04:58:13,610 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz
# 251107-04:58:47,424 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 109.378794s.
# 251107-04:58:47,430 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/e ...
# 251107-04:58:47,431 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-04:58:47,432 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:47,432 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-04:58:47,437 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-04:58:51,827 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 113.768373s.
# 251107-04:58:51,832 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/e ...
# 251107-04:58:51,833 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-04:58:51,834 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:51,835 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-04:58:51,838 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-04:58:51,843 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 113.791641s.
# 251107-04:58:51,847 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.n ...
# 251107-04:58:51,847 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-04:58:51,852 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:51,854 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-04:58:51,858 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"

# %%
#didn't work
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [5], 
                                                     nb_param, ['derivatives','no_derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-04:58:18,133 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:23,294 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:28,449 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:33,603 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:42,513 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# No use derivatives
# 251107-04:58:47,664 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:52,816 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:58,6 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-04:58:58,13 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-04:58:58,14 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-04:58:58,16 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-04:58:58,16 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-04:58:58,17 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-04:58:58,18 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-04:58:58,19 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-04:58:58,20 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-04:58:58,21 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-04:58:58,23 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-04:58:58,23 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-04:58:58,24 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-04:58:58,25 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:58:58,26 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-04:58:58,26 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-04:58:58,28 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-04:58:58,28 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-04:58:58,29 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-04:58:58,30 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-04:58:58,30 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-04:58:58,33 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-04:58:58,36 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-04:58:58,43 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-04:58:58,44 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-04:58:58,45 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-04:58:58,45 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-04:58:58,47 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-04:58:58,47 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-04:58:58,49 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-04:58:58,49 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-04:58:58,50 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-04:58:58,50 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-04:58:58,51 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-04:58:58,55 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-04:58:58,56 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-04:58:58,58 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-04:58:58,58 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf40280>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf404c0>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf40e50>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe3cfa670>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf63c10>}
# 251107-04:58:58,59 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-04:58:58,66 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,67 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:58:58,67 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:58:58,67 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,68 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,68 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:58:58,74 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,74 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:58:58,75 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-04:58:58,75 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,75 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,77 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-04:58:58,80 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,80 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:58:58,81 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-04:58:58,81 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,81 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,82 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-04:58:58,84 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,85 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:58:58,85 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-04:58:58,86 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,86 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,86 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-04:58:58,88 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,88 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-04:58:58,89 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-04:58:58,89 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,89 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,89 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-04:58:58,92 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-04:58:58,92 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-04:58:58,93 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-04:58:58,93 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-04:58:58,93 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-04:58:58,94 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-04:58:58,94 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-04:58:58,94 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,95 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,95 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,95 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,96 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,96 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,96 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,96 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,97 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,97 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,97 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,98 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,98 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,98 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,98 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,99 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,99 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,99 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,100 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,100 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,101 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-04:58:58,101 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-04:58:58,101 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-04:58:58,101 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-04:58:58,113 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-04:58:58,121 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-04:58:58,130 nipype.workflow DEBUG:
# 	 Progress: 42 jobs, 0/0/6 (done/running/ready), 0/42 (pending_tasks/waiting).
# 251107-04:58:58,130 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-04:58:58,131 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-04:58:58,202 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-04:58:58,205 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,206 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,206 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,271 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-04:58:58,272 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-04:58:58,275 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,275 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,276 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,277 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-04:58:58,278 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=2 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-04:58:58,274 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,281 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,279 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,281 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,282 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,283 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=3).
# 251107-04:58:58,284 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=3 (0.20GB, 1 threads). Free: 6.09GB, 12 threads.
# 251107-04:58:58,285 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,287 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,287 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,288 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,290 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=4).
# 251107-04:58:58,291 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=4 (0.20GB, 1 threads). Free: 5.89GB, 11 threads.
# 251107-04:58:58,290 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,290 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,291 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,290 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,292 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,293 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,293 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,293 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,294 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,296 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,297 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,296 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,297 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,295 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,299 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=5).
# 251107-04:58:58,297 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,300 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=5 (0.20GB, 1 threads). Free: 5.69GB, 10 threads.
# 251107-04:58:58,299 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,298 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,300 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,302 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,302 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,305 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,305 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,306 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,307 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,307 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,308 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,309 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-04:58:58,310 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=6).
# 251107-04:58:58,311 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,311 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-04:58:58,315 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,317 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-04:58:58,317 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,317 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,318 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-04:58:58,319 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,320 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-04:58:58,323 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-04:58:58,325 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,327 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,329 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,330 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,331 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,338 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,338 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,340 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.00644s.
# 251107-04:58:58,340 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.00962s.
# 251107-04:58:58,340 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.007069s.
# 251107-04:58:58,343 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.009536s.
# 251107-04:58:58,351 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,352 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,350 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-04:58:58,351 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002266s.
# 251107-04:58:58,352 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,355 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:58,354 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,354 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,356 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:58:58,357 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:58,357 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,358 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,359 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:58:58,359 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,360 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:58,360 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:58,362 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:58:58,362 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:58:58,362 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003401s.
# 251107-04:58:58,365 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,366 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,368 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,370 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,370 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-04:58:58,371 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,373 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-04:58:58,375 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-04:58:58,377 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-04:58:58,378 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-04:58:58,379 nipype.workflow DEBUG:
# ...
# 251107-05:00:25,453 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 77.131076s.
# 251107-05:00:25,459 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/e ...
# 251107-05:00:25,460 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:00:25,461 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:00:25,462 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:00:25,467 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-05:00:31,68 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 82.743899s.
# 251107-05:00:31,72 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/inte ...
# 251107-05:00:31,73 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:00:31,74 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:00:31,75 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:00:31,77 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-05:00:31,155 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 82.782807s.
# 251107-05:00:31,158 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl ...
# 251107-05:00:31,159 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:00:31,160 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:00:31,160 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:00:31,163 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"

# %%
#worked
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [5], 
                                                     [6,24], ['derivatives','no_derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-05:02:12,153 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:17,354 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:22,538 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:27,726 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:32,909 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# No use derivatives
# 251107-05:02:38,107 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:43,295 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:48,479 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:02:48,486 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-05:02:48,488 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-05:02:48,489 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-05:02:48,490 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-05:02:48,491 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-05:02:48,492 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-05:02:48,493 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-05:02:48,494 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-05:02:48,495 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-05:02:48,497 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-05:02:48,498 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-05:02:48,499 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-05:02:48,499 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:02:48,500 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-05:02:48,500 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:02:48,501 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-05:02:48,502 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-05:02:48,502 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-05:02:48,502 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-05:02:48,503 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-05:02:48,507 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-05:02:48,514 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-05:02:48,530 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-05:02:48,531 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-05:02:48,532 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-05:02:48,534 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-05:02:48,536 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-05:02:48,536 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-05:02:48,537 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-05:02:48,538 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-05:02:48,539 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-05:02:48,539 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-05:02:48,540 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-05:02:48,545 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-05:02:48,546 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-05:02:48,548 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-05:02:48,549 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf40e50>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf40430>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf40310>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf403a0>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe010c550>}
# 251107-05:02:48,550 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-05:02:48,555 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-05:02:48,555 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-05:02:48,556 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-05:02:48,556 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:02:48,557 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:02:48,557 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-05:02:48,563 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-05:02:48,564 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:02:48,564 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-05:02:48,564 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:02:48,565 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:02:48,565 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-05:02:48,569 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-05:02:48,569 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-05:02:48,570 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-05:02:48,570 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:02:48,570 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:02:48,571 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-05:02:48,572 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 5
# 251107-05:02:48,573 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:02:48,573 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-05:02:48,573 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:02:48,574 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:02:48,574 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-05:02:48,574 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-05:02:48,575 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:02:48,576 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:02:48,576 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-05:02:48,577 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:02:48,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:02:48,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:02:48,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-05:02:48,578 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:02:48,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:02:48,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:02:48,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-05:02:48,579 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:02:48,579 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:02:48,580 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:02:48,580 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 5
# 251107-05:02:48,580 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:02:48,590 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-05:02:48,596 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-05:02:48,600 nipype.workflow DEBUG:
# 	 Progress: 28 jobs, 0/0/4 (done/running/ready), 0/28 (pending_tasks/waiting).
# 251107-05:02:48,600 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:02:48,603 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:02:48,659 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:02:48,663 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,663 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,664 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:02:48,743 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-05:02:48,746 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:02:48,751 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,751 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,752 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:02:48,748 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:02:48,753 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-05:02:48,754 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=2 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-05:02:48,755 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:02:48,760 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,760 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,761 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:02:48,762 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=3).
# 251107-05:02:48,761 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,763 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=3 (0.20GB, 1 threads). Free: 6.09GB, 12 threads.
# 251107-05:02:48,762 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,763 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,764 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,764 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:02:48,766 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:02:48,764 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:02:48,768 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:02:48,770 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,770 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,770 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:02:48,770 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,771 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:02:48,773 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=4).
# 251107-05:02:48,772 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,774 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:02:48,778 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:02:48,776 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:02:48,785 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 5), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], bc082a9699f90426085cd1ea6bff1e5b, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b.json']
# 251107-05:02:48,786 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:02:48,786 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:02:48,788 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:02:48,790 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,791 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,793 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,799 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,800 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:02:48,800 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:02:48,803 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:02:48,806 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:02:48,810 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.005129s.
# 251107-05:02:48,810 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.007458s.
# 251107-05:02:48,812 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002994s.
# 251107-05:02:48,813 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003008s.
# 251107-05:02:48,817 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:02:48,817 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:02:48,818 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:02:48,818 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:02:48,819 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:02:48,819 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:02:48,820 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:02:48,820 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:02:48,820 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:02:48,821 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:02:48,821 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_5_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0xbc082a9699f90426085cd1ea6bff1e5b_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:02:48,822 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:02:48,822 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:02:48,823 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:02:48,824 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:02:48,825 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:02:48,826 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,827 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,829 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:48,832 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:02:50,610 nipype.workflow DEBUG:
# 	 Progress: 28 jobs, 0/4/0 (done/running/ready), 4/24 (pending_tasks/waiting).
# 251107-05:02:50,612 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:02:50,621 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:02:50,625 nipype.workflow INFO:
# 	 [Job 2] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:02:50,626 nipype.workflow INFO:
# 	 [Job 3] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:02:50,628 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:02:50,630 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:02:50,703 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=4 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:02:50,704 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-05:02:50,705 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:02:50,706 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:02:50,706 nipype.workflow DEBUG:
# 	 output: event
# 251107-05:02:50,707 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-05:02:50,712 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-05:02:50,713 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-05:02:50,713 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-05:02:50,713 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 4.
# 251107-05:02:50,714 nipype.workflow INFO:
# 	 [Job 4] Cached (l1_analysis_fsl.subject_infos).
# 251107-05:02:50,715 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=5 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:02:50,716 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-05:02:50,717 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:02:50,717 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:02:50,718 nipype.workflow DEBUG:
# 	 output: event
# 251107-05:02:50,718 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-05:02:50,719 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-05:02:50,720 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-05:02:50,720 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-05:02:50,720 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 5.
# 251107-05:02:50,720 nipype.workflow INFO:
# 	 [Job 5] Cached (l1_analysis_fsl.subject_infos).
# 251107-05:02:50,721 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=6 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-05:02:50,723 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-05:02:50,724 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:02:50,724 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:02:50,725 nipype.workflow DEBUG:
# 	 output: event
# 251107-05:02:50,725 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-05:02:50,727 nipype.workflow DEBUG:
# ...
# 251107-05:03:03,692 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile already exists,845f55cf5d5a18389924d75ffd8c4104, copy:1
# 251107-05:03:03,693 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile already exists, not overwriting, copy:1
# 251107-05:03:03,693 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz
# 251107-05:03:03,696 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists,43966da17557d221b0ca20f1cac53b25, copy:1
# 251107-05:03:03,698 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,699 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz
# 251107-05:03:03,701 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists,43966da17557d221b0ca20f1cac53b25, copy:1
# 251107-05:03:03,703 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,704 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-05:03:03,707 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists,00cbbad786442a55280baeb3e14d856d, copy:1
# 251107-05:03:03,709 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,710 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-05:03:03,712 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists,00cbbad786442a55280baeb3e14d856d, copy:1
# 251107-05:03:03,714 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,715 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-05:03:03,718 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists,00cbbad786442a55280baeb3e14d856d, copy:1
# 251107-05:03:03,720 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,721 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-05:03:03,723 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists,00cbbad786442a55280baeb3e14d856d, copy:1
# 251107-05:03:03,725 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,726 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-05:03:03,729 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists,07be59d9d996fc90b29280205377a8f0, copy:1
# 251107-05:03:03,734 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,734 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-05:03:03,736 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists,07be59d9d996fc90b29280205377a8f0, copy:1
# 251107-05:03:03,739 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,739 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-05:03:03,742 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists,326f35bb2ca26c4e124e0b0669413344, copy:1
# 251107-05:03:03,745 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,746 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-05:03:03,748 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists,326f35bb2ca26c4e124e0b0669413344, copy:1
# 251107-05:03:03,751 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,752 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-05:03:03,754 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists,e5dd7899db00026589b3434e1b7940da, copy:1
# 251107-05:03:03,757 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,757 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-05:03:03,760 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists,e5dd7899db00026589b3434e1b7940da, copy:1
# 251107-05:03:03,762 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,762 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-05:03:03,765 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,de907b775ecec35b6c6ab4567b8f095e, copy:1
# 251107-05:03:03,768 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,769 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-05:03:03,771 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,de907b775ecec35b6c6ab4567b8f095e, copy:1
# 251107-05:03:03,773 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-05:03:03,774 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 2.98795s.
# 251107-05:03:03,776 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_0xe41eb7d6272a668ac8f09ce844e535b3_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_node.pklz
# 251107-05:03:03,777 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-05:03:03,777 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:03:03,778 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-05:03:03,779 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_5_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-05:03:04,637 nipype.workflow INFO:
# 	 [Job 24] Completed (l1_analysis_fsl.datasink).
# 251107-05:03:04,641 nipype.workflow INFO:
# 	 [Job 25] Completed (l1_analysis_fsl.datasink).
# 251107-05:03:04,643 nipype.workflow INFO:
# 	 [Job 26] Completed (l1_analysis_fsl.datasink).
# 251107-05:03:04,646 nipype.workflow INFO:
# 	 [Job 27] Completed (l1_analysis_fsl.datasink).
# 251107-05:03:04,648 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:03:04,652 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:03:04,653 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock

# %%
#didn't work
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [8], 
                                                     [0,6,24], ['derivatives','no_derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-05:04:39,203 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:04:44,380 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:04:49,552 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:04:54,736 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:04:59,923 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# No use derivatives
# 251107-05:05:05,100 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:05:10,277 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:05:15,479 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:05:15,485 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-05:05:15,486 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-05:05:15,487 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-05:05:15,487 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-05:05:15,488 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-05:05:15,489 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-05:05:15,490 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-05:05:15,491 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-05:05:15,494 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-05:05:15,494 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-05:05:15,495 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-05:05:15,496 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-05:05:15,497 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:05:15,498 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-05:05:15,499 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:05:15,500 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-05:05:15,501 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-05:05:15,501 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-05:05:15,502 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-05:05:15,502 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-05:05:15,505 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-05:05:15,506 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-05:05:15,511 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-05:05:15,513 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-05:05:15,514 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-05:05:15,515 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-05:05:15,517 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-05:05:15,518 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-05:05:15,518 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-05:05:15,519 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-05:05:15,520 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-05:05:15,521 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-05:05:15,525 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-05:05:15,541 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-05:05:15,542 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-05:05:15,543 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-05:05:15,543 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00a55e0>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00a54c0>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00a5a60>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00a51f0>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffe00a5d30>}
# 251107-05:05:15,544 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-05:05:15,547 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,549 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-05:05:15,549 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-05:05:15,549 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,550 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,551 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-05:05:15,553 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,554 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:05:15,554 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 0
# 251107-05:05:15,555 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,555 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,555 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING
# 251107-05:05:15,557 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,558 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-05:05:15,558 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-05:05:15,558 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,559 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,559 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-05:05:15,561 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,562 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:05:15,562 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-05:05:15,562 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,563 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,563 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-05:05:15,566 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,567 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = derivatives
# 251107-05:05:15,567 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-05:05:15,567 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,567 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,568 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-05:05:15,569 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:05:15,570 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:05:15,570 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-05:05:15,571 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:05:15,571 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:05:15,571 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-05:05:15,572 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-05:05:15,572 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,573 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,573 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,573 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,574 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,574 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,574 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,575 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,575 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,575 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,576 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,576 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,576 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,577 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,577 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,578 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,578 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:05:15,579 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:05:15,579 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:05:15,579 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:05:15,593 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-05:05:15,597 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-05:05:15,599 nipype.workflow DEBUG:
# 	 Progress: 42 jobs, 0/0/6 (done/running/ready), 0/42 (pending_tasks/waiting).
# 251107-05:05:15,601 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:05:15,601 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:05:15,640 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:05:15,642 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,642 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,642 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,696 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-05:05:15,697 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:05:15,699 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,699 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,700 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,701 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,703 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-05:05:15,703 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=2 (0.20GB, 1 threads). Free: 6.29GB, 13 threads.
# 251107-05:05:15,704 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,704 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,705 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,706 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,706 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,707 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,708 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,709 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=3).
# 251107-05:05:15,709 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=3 (0.20GB, 1 threads). Free: 6.09GB, 12 threads.
# 251107-05:05:15,710 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,710 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,711 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,713 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,711 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,713 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,714 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,715 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,715 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,717 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=4).
# 251107-05:05:15,715 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,717 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,718 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,719 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=4 (0.20GB, 1 threads). Free: 5.89GB, 11 threads.
# 251107-05:05:15,718 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,719 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,723 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,723 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,721 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,724 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,721 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,725 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=5).
# 251107-05:05:15,726 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=5 (0.20GB, 1 threads). Free: 5.69GB, 10 threads.
# 251107-05:05:15,727 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,728 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,728 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,727 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,730 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,732 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,732 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,732 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,733 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,733 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,735 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:05:15,734 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,734 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,736 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,737 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=6).
# 251107-05:05:15,738 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,738 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:05:15,739 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,742 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.004752s.
# 251107-05:05:15,743 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.00568s.
# 251107-05:05:15,745 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,747 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:05:15,748 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.004227s.
# 251107-05:05:15,749 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:05:15,751 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:05:15,753 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:05:15,753 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,754 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,755 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,756 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,756 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,758 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:05:15,760 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,761 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,761 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,763 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,763 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,763 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.003023s.
# 251107-05:05:15,765 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,766 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:05:15,766 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:05:15,768 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,769 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,770 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,771 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,773 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,776 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.004017s.
# 251107-05:05:15,779 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,783 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,782 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:05:15,784 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,786 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:05:15,788 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.002184s.
# 251107-05:05:15,792 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:05:15,792 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,794 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,795 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,796 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:05:15,796 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:05:15,797 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:05:15,799 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:05:15,800 nipype.workflow DEBUG:
# ...
# 251107-05:05:58,669 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz
# 251107-05:06:25,932 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 60.115925s.
# 251107-05:06:25,939 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/e ...
# 251107-05:06:25,940 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:06:25,941 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:06:25,942 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:06:25,946 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-05:06:31,502 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 65.741619s.
# 251107-05:06:31,515 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/inte ...
# 251107-05:06:31,516 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:06:31,517 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:06:31,518 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:06:31,523 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_0_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"
# 251107-05:06:31,649 nipype.workflow INFO:
# 	 [Node] Finished "model_estimate", elapsed time 65.844697s.
# 251107-05:06:31,653 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/pe5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/res4d.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/dof;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/sigmasquareds.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/threshac1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/logfile;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/cope5.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope1.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope2.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope3.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/inte ...
# 251107-05:06:31,654 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report
# 251107-05:06:31,654 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:06:31,655 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/result_model_estimate.pklz'
# 251107-05:06:31,657 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/model_estimate/_report/report.rst"

# %%
#worked
for subjects in subject_list:
    l1_analysis = fsl_pipelines.get_l1_analysis(exp_dir, output_dir, working_dir, result_dir, 
                                                     [subjects], task_list, contrast_list, [8], 
                                                     [6,24], ['no_derivatives'])
    l1_analysis.run('MultiProc', plugin_args={'n_procs': 16})
# Out:
# 251107-05:08:39,164 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:08:44,351 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:08:49,530 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:08:54,700 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:08:59,888 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# No use derivatives
# 251107-05:09:05,86 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:09:10,268 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:09:15,471 nipype.utils DEBUG:
# 	 Could not check nipy/nipype for version updates: No response from server in 5 seconds
# 251107-05:09:15,480 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): No edge data
# 251107-05:09:15,482 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles): new edge data: {'connect': [('subject_id', 'subject_id'), ('task', 'task'), ('fwhm', 'fwhm')]}
# 251107-05:09:15,483 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): No edge data
# 251107-05:09:15,484 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos): new edge data: {'connect': [('event', 'event_file')]}
# 251107-05:09:15,485 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): No edge data
# 251107-05:09:15,486 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.specify_model): new edge data: {'connect': [('func', 'functional_runs')]}
# 251107-05:09:15,488 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): No edge data
# 251107-05:09:15,489 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model): new edge data: {'connect': [('subject_info', 'subject_info')]}
# 251107-05:09:15,490 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): No edge data
# 251107-05:09:15,491 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design): new edge data: {'connect': [('session_info', 'session_info')]}
# 251107-05:09:15,491 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): No edge data
# 251107-05:09:15,492 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation): new edge data: {'connect': [('ev_files', 'ev_files'), ('fsf_files', 'fsf_file')]}
# 251107-05:09:15,494 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:09:15,494 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.selectfiles, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('func', 'in_file')]}
# 251107-05:09:15,495 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): No edge data
# 251107-05:09:15,496 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate): new edge data: {'connect': [('con_file', 'tcon_file'), ('design_file', 'design_file')]}
# 251107-05:09:15,497 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): No edge data
# 251107-05:09:15,499 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink): new edge data: {'connect': [('results_dir', 'l1_analysis_fsl.@results')]}
# 251107-05:09:15,499 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): No edge data
# 251107-05:09:15,500 nipype.workflow DEBUG:
# 	 (l1_analysis_fsl.model_generation, l1_analysis_fsl.datasink): new edge data: {'connect': [('design_file', 'l1_analysis_fsl.@design_file'), ('design_image', 'l1_analysis_fsl.@design_img')]}
# 251107-05:09:15,505 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=16, mem_gb=6.89, cwd=/srv/tempdd/egermani/hcp_pipelines/src)
# 251107-05:09:15,510 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: l1_analysis_fsl
# 251107-05:09:15,517 nipype.workflow DEBUG:
# 	 expanding workflow: l1_analysis_fsl
# 251107-05:09:15,518 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.infosource
# 251107-05:09:15,520 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.selectfiles
# 251107-05:09:15,520 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.subject_infos
# 251107-05:09:15,521 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.specify_model
# 251107-05:09:15,522 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.l1_design
# 251107-05:09:15,523 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_generation
# 251107-05:09:15,523 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.model_estimate
# 251107-05:09:15,524 nipype.workflow DEBUG:
# 	 processing node: l1_analysis_fsl.datasink
# 251107-05:09:15,524 nipype.workflow DEBUG:
# 	 finished expanding workflow: l1_analysis_fsl
# 251107-05:09:15,525 nipype.workflow INFO:
# 	 Workflow l1_analysis_fsl settings: ['check', 'execution', 'logging', 'monitoring']
# 251107-05:09:15,527 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 251107-05:09:15,528 nipype.workflow DEBUG:
# 	 Detected iterable nodes [l1_analysis_fsl.infosource]
# 251107-05:09:15,528 nipype.workflow DEBUG:
# 	 Expanding the iterable node l1_analysis_fsl.infosource...
# 251107-05:09:15,529 nipype.workflow DEBUG:
# 	 node: l1_analysis_fsl.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf63d30>, 'task': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf63f70>, 'fwhm': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf63a60>, 'nb_param': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf63430>, 'hrf': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7fffdbf634c0>}
# 251107-05:09:15,529 nipype.workflow DEBUG:
# 	 ('subnodes:', [l1_analysis_fsl.infosource, l1_analysis_fsl.selectfiles, l1_analysis_fsl.subject_infos, l1_analysis_fsl.specify_model, l1_analysis_fsl.l1_design, l1_analysis_fsl.model_generation, l1_analysis_fsl.model_estimate, l1_analysis_fsl.datasink])
# 251107-05:09:15,535 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:09:15,540 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:09:15,540 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 6
# 251107-05:09:15,541 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:09:15,541 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:09:15,541 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING
# 251107-05:09:15,551 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input fwhm = 8
# 251107-05:09:15,551 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input hrf = no_derivatives
# 251107-05:09:15,552 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input nb_param = 24
# 251107-05:09:15,552 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 131823
# 251107-05:09:15,552 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input task = GAMBLING
# 251107-05:09:15,553 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING
# 251107-05:09:15,553 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 251107-05:09:15,553 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:09:15,554 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:09:15,554 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:09:15,555 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:09:15,555 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input subject_id = 131823
# 251107-05:09:15,556 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input task = GAMBLING
# 251107-05:09:15,556 nipype.workflow DEBUG:
# 	 [Node] selectfiles - setting input fwhm = 8
# 251107-05:09:15,557 nipype.workflow DEBUG:
# 	 Removed the identity node l1_analysis_fsl.infosource from the graph.
# 251107-05:09:15,566 nipype.workflow DEBUG:
# 	 Performing depth first search
# 251107-05:09:15,571 nipype.workflow INFO:
# 	 Running in parallel.
# 251107-05:09:15,576 nipype.workflow DEBUG:
# 	 Progress: 14 jobs, 0/0/2 (done/running/ready), 0/14 (pending_tasks/waiting).
# 251107-05:09:15,577 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:09:15,578 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:09:15,650 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=0 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:09:15,654 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:09:15,654 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:09:15,655 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:09:15,731 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=1).
# 251107-05:09:15,734 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.selectfiles ID=1 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:09:15,739 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:09:15,740 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:09:15,740 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.selectfiles" locally: cached=True, updated=True.
# 251107-05:09:15,742 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task l1_analysis_fsl.selectfiles (taskid=2).
# 251107-05:09:15,737 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:09:15,743 nipype.workflow INFO:
# 	 [Node] Setting-up "l1_analysis_fsl.selectfiles" in "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles".
# 251107-05:09:15,752 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:09:15,752 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/srv/tempdd/egermani/hcp_pipelines/data/derived'), ('force_lists', False), ('fwhm', 8), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '131823'), ('task', 'GAMBLING')], 631ecf374c4cd337641af78187be8d00, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00.json']
# 251107-05:09:15,754 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:09:15,754 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.selectfiles".
# 251107-05:09:15,755 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:09:15,755 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "l1_analysis_fsl.selectfiles"
# 251107-05:09:15,757 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:09:15,757 nipype.utils DEBUG:
# 	 Removing contents of /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles
# 251107-05:09:15,770 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:09:15,772 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:09:15,777 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:09:15,779 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 251107-05:09:15,786 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.005614s.
# 251107-05:09:15,786 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.004575s.
# 251107-05:09:15,791 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:09:15,792 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:09:15,791 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_realign0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf.nii.gz.par;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt;/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_0x631ecf374c4cd337641af78187be8d00_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_node.pklz
# 251107-05:09:15,793 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:09:15,793 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report
# 251107-05:09:15,794 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:09:15,794 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:09:15,795 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz'
# 251107-05:09:15,797 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:09:15,798 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/_report/report.rst"
# 251107-05:09:17,587 nipype.workflow DEBUG:
# 	 Progress: 14 jobs, 0/2/0 (done/running/ready), 2/12 (pending_tasks/waiting).
# 251107-05:09:17,590 nipype.workflow INFO:
# 	 [Job 0] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:09:17,594 nipype.workflow INFO:
# 	 [Job 1] Completed (l1_analysis_fsl.selectfiles).
# 251107-05:09:17,597 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:09:17,598 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:09:17,685 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=2 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:09:17,688 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-05:09:17,689 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:09:17,691 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:17,691 nipype.workflow DEBUG:
# 	 output: event
# 251107-05:09:17,691 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-05:09:17,696 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-05:09:17,696 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-05:09:17,697 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-05:09:17,698 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 2.
# 251107-05:09:17,698 nipype.workflow INFO:
# 	 [Job 2] Cached (l1_analysis_fsl.subject_infos).
# 251107-05:09:17,700 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.subject_infos ID=3 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:09:17,701 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "subject_infos" from 1 previous nodes.
# 251107-05:09:17,702 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:09:17,702 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:17,703 nipype.workflow DEBUG:
# 	 output: event
# 251107-05:09:17,703 nipype.workflow DEBUG:
# 	 [Node] subject_infos - setting input event_file = ['/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt']
# 251107-05:09:17,704 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('contrasts', ['win_event', 'neut_event', 'loss_event', 'win', 'loss']), ('event_file', [('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/Sync.txt', 'b01d8973f9093b04a0877dbf99e43bd1'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss.txt', '5bef8287386287007189e02c5e973019'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/loss_event.txt', 'c4a525b8b058ce89aff2f7b83235038f'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/neut_event.txt', '249870eebce02a5d39e52210bda7b785'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win.txt', '79964f4dc33f85e2a622b8fce550e4e6'), ('/srv/tempdd/egermani/hcp_pipelines/data/original/131823/unprocessed/3T/tfMRI_GAMBLING_LR/LINKED_DATA/EPRIME/EVs/win_event.txt', 'aef7fe362d964f58a848ca60d1ca3d76')]), ('function_str', "def get_subject_infos(event_file, contrasts):\n\t'''\n\tCreate Bunchs for specifyModel.\n\tParameters :\n\t- event_file: list of str, event files for the subject\n\t- contrasts: list of contrast to analyze\n\n\tReturns :\n\t- subject_info : Bunch for 1st level analysis.\n\t'''\n\tfrom nipype.interfaces.base import Bunch\n\timport numpy as np\n\n\t# Global lists \n\tcond_names = sorted(contrasts) \n\tonsets = []\n\tdurations = []\n\n\t# Selection of only event files corresponding to selected contrasts\n\tevent_files = [f for f in sorted(event_file) if f.split('/')[-1].split('.')[0] in contrasts]\n\n\tfor i, c in enumerate(sorted(contrasts)):\n\t\tonset = [] # For each contrast, save the onset and duration\n\t\tduration = []\n\t\tfile = sorted(event_files)[i]\n\t\twith open(file, 'rt') as f:\n\t\t\tfor line in f:\n\t\t\t\tinfo = line.strip().split()\n\n\t\t\t\tonset.append(float(info[0])) \n\t\t\t\tduration.append(float(info[1]))\n\t\tonsets.append(onset)\n\t\tdurations.append(duration) # Add these onset and duration to global list \n\n\tsubject_info = Bunch(conditions=cond_names,\n\t\t\t\t\t\t\t onsets=onsets, # Onsets and Durations contain list of lists with onsets and durations for every contrast\n\t\t\t\t\t\t\t durations=durations,\n\t\t\t\t\t\t\t amplitudes=None,\n\t\t\t\t\t\t\t regressor_names=None,\n\t\t\t\t\t\t\t regressors=None)\n\n\treturn subject_info\n")], 2d2acefde1e27d15aeb764a13eb907a0, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos/_0x2d2acefde1e27d15aeb764a13eb907a0.json']
# 251107-05:09:17,705 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.subject_infos".
# 251107-05:09:17,705 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.subject_infos" locally: cached=True, updated=True.
# 251107-05:09:17,705 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.subject_infos with ID 3.
# 251107-05:09:17,705 nipype.workflow INFO:
# 	 [Job 3] Cached (l1_analysis_fsl.subject_infos).
# 251107-05:09:19,592 nipype.workflow DEBUG:
# 	 Progress: 14 jobs, 4/0/2 (done/running/ready), 0/10 (pending_tasks/waiting).
# 251107-05:09:19,594 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:09:19,660 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.specify_model ID=4 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:09:19,662 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "specify_model" from 2 previous nodes.
# 251107-05:09:19,663 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:09:19,665 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:19,665 nipype.workflow DEBUG:
# 	 output: func
# 251107-05:09:19,666 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input functional_runs = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-05:09:19,667 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/subject_infos/result_subject_infos.pklz
# 251107-05:09:19,669 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:19,669 nipype.workflow DEBUG:
# 	 output: subject_info
# 251107-05:09:19,669 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input subject_info = Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)
# 251107-05:09:19,671 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bids_condition_column', 'trial_type'), ('functional_runs', [('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '21b28def444b22e675a6e9b1da70184f')]), ('high_pass_filter_cutoff', '60.0000000000'), ('input_units', 'secs'), ('parameter_source', 'SPM'), ('subject_info', [Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)]), ('time_repetition', '0.7200000000')], d5730e57cda22a9f06d41eb6386fe86d, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json']
# 251107-05:09:19,671 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.specify_model".
# 251107-05:09:19,671 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.specify_model" locally: cached=True, updated=True.
# 251107-05:09:19,672 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.specify_model with ID 4.
# 251107-05:09:19,672 nipype.workflow INFO:
# 	 [Job 4] Cached (l1_analysis_fsl.specify_model).
# 251107-05:09:19,673 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.specify_model ID=5 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:09:19,674 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "specify_model" from 2 previous nodes.
# 251107-05:09:19,674 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/selectfiles/result_selectfiles.pklz
# 251107-05:09:19,676 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:19,676 nipype.workflow DEBUG:
# 	 output: func
# 251107-05:09:19,677 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input functional_runs = /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz
# 251107-05:09:19,677 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/subject_infos/result_subject_infos.pklz
# 251107-05:09:19,679 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:19,679 nipype.workflow DEBUG:
# 	 output: subject_info
# 251107-05:09:19,679 nipype.workflow DEBUG:
# 	 [Node] specify_model - setting input subject_info = Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)
# 251107-05:09:19,680 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bids_condition_column', 'trial_type'), ('functional_runs', [('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/preprocess_fsl/_fwhm_8_subject_id_131823_task_GAMBLING/_addmean0/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '21b28def444b22e675a6e9b1da70184f')]), ('high_pass_filter_cutoff', '60.0000000000'), ('input_units', 'secs'), ('parameter_source', 'SPM'), ('subject_info', [Bunch(amplitudes=None, conditions=['loss', 'loss_event', 'neut_event', 'win', 'win_event'], durations=[[28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5], [3.5, 3.5], [28.0, 28.0], [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]], onsets=[[8.063, 95.855], [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], [55.577, 73.65], [51.965, 139.704], [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0]], regressor_names=None, regressors=None)]), ('time_repetition', '0.7200000000')], d5730e57cda22a9f06d41eb6386fe86d, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/specify_model/_0xd5730e57cda22a9f06d41eb6386fe86d.json']
# 251107-05:09:19,680 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.specify_model".
# 251107-05:09:19,680 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.specify_model" locally: cached=True, updated=True.
# 251107-05:09:19,681 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.specify_model with ID 5.
# 251107-05:09:19,681 nipype.workflow INFO:
# 	 [Job 5] Cached (l1_analysis_fsl.specify_model).
# 251107-05:09:21,596 nipype.workflow DEBUG:
# 	 Progress: 14 jobs, 6/0/2 (done/running/ready), 0/8 (pending_tasks/waiting).
# 251107-05:09:21,599 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:09:21,659 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.l1_design ID=6 (0.20GB, 1 threads). Free: 6.69GB, 15 threads.
# 251107-05:09:21,662 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "l1_design" from 1 previous nodes.
# 251107-05:09:21,664 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/specify_model/result_specify_model.pklz
# 251107-05:09:21,666 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:21,667 nipype.workflow DEBUG:
# 	 output: session_info
# 251107-05:09:21,668 nipype.workflow DEBUG:
# 	 [Node] l1_design - setting input session_info = [{'cond': [{'name': 'loss', 'onset': [8.063, 95.855], 'duration': [28.0, 28.0]}, {'name': 'loss_event', 'onset': [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}, {'name': 'neut_event', 'onset': [55.577, 73.65], 'duration': [3.5, 3.5]}, {'name': 'win', 'onset': [51.965, 139.704], 'duration': [28.0, 28.0]}, {'name': 'win_event', 'onset': [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}], 'hpf': 60.0, 'regress': [], 'scans': '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/specify_model/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz'}]
# 251107-05:09:21,671 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bases', [('dgamma', [('derivs', False)])]), ('contrasts', [('loss vs baseline', 'T', ['loss'], ['1.0000000000']), ('loss_event vs baseline', 'T', ['loss_event'], ['1.0000000000']), ('neut_event vs baseline', 'T', ['neut_event'], ['1.0000000000']), ('win vs baseline', 'T', ['win'], ['1.0000000000']), ('win_event vs baseline', 'T', ['win_event'], ['1.0000000000'])]), ('interscan_interval', '0.7200000000'), ('model_serial_correlations', True), ('orthogonalization', []), ('session_info', [[('cond', [[('duration', ['28.0000000000', '28.0000000000']), ('name', 'loss'), ('onset', ['8.0630000000', '95.8550000000'])], [('duration', ['3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000']), ('name', 'loss_event'), ('onset', ['8.0630000000', '11.6880000000', '18.8990000000', '26.1360000000', '29.7480000000', '33.3600000000', '95.8550000000', '99.4660000000', '106.6640000000', '113.8740000000', '117.4860000000', '121.0980000000', '146.9280000000', '154.1650000000'])], [('duration', ['3.5000000000', '3.5000000000']), ('name', 'neut_event'), ('onset', ['55.5770000000', '73.6500000000'])], [('duration', ['28.0000000000', '28.0000000000']), ('name', 'win'), ('onset', ['51.9650000000', '139.7040000000'])], [('duration', ['3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000', '3.5000000000']), ('name', 'win_event'), ('onset', ['15.3000000000', '22.5110000000', '51.9650000000', '59.1890000000', '62.8010000000', '66.4260000000', '70.0380000000', '77.2490000000', '103.0650000000', '110.2620000000', '139.7040000000', '143.3160000000', '150.5530000000', '157.7760000000', '161.4020000000', '165.0000000000'])]]), ('hpf', '60.0000000000'), ('regress', []), ('scans', ('/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/specify_model/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz', '21b28def444b22e675a6e9b1da70184f'))]])], 5b6d8a378888dd9f1e5c16f0d5c987ce, /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/l1_design/_0x5b6d8a378888dd9f1e5c16f0d5c987ce.json, ['/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_6_subject_id_131823_task_GAMBLING/l1_design/_0x5b6d8a378888dd9f1e5c16f0d5c987ce.json']
# 251107-05:09:21,671 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "l1_analysis_fsl.l1_design".
# 251107-05:09:21,672 nipype.workflow DEBUG:
# 	 Checking hash "l1_analysis_fsl.l1_design" locally: cached=True, updated=True.
# 251107-05:09:21,672 nipype.workflow DEBUG:
# 	 Skipping cached node l1_analysis_fsl.l1_design with ID 6.
# 251107-05:09:21,672 nipype.workflow INFO:
# 	 [Job 6] Cached (l1_analysis_fsl.l1_design).
# 251107-05:09:21,673 nipype.workflow DEBUG:
# 	 Allocating l1_analysis_fsl.l1_design ID=7 (0.20GB, 1 threads). Free: 6.49GB, 14 threads.
# 251107-05:09:21,675 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "l1_design" from 1 previous nodes.
# 251107-05:09:21,675 nipype.utils DEBUG:
# 	 Loading pkl: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/specify_model/result_specify_model.pklz
# 251107-05:09:21,676 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 251107-05:09:21,677 nipype.workflow DEBUG:
# 	 output: session_info
# 251107-05:09:21,677 nipype.workflow DEBUG:
# 	 [Node] l1_design - setting input session_info = [{'cond': [{'name': 'loss', 'onset': [8.063, 95.855], 'duration': [28.0, 28.0]}, {'name': 'loss_event', 'onset': [8.063, 11.688, 18.899, 26.136, 29.748, 33.36, 95.855, 99.466, 106.664, 113.874, 117.486, 121.098, 146.928, 154.165], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}, {'name': 'neut_event', 'onset': [55.577, 73.65], 'duration': [3.5, 3.5]}, {'name': 'win', 'onset': [51.965, 139.704], 'duration': [28.0, 28.0]}, {'name': 'win_event', 'onset': [15.3, 22.511, 51.965, 59.189, 62.801, 66.426, 70.038, 77.249, 103.065, 110.262, 139.704, 143.316, 150.553, 157.776, 161.402, 165.0], 'duration': [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5]}], 'hpf': 60.0, 'regress': [], 'scans': '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/specify_model/131823_3T_tfMRI_GAMBLING_LR_dtype_mcf_mask_smooth_mask_gms_tempfilt_maths.nii.gz'}]
# 251107-05:09:21,679 nipype.workflow DEBUG:
# ...
# 251107-05:10:01,45 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile
# 251107-05:10:01,45 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/logfile
# 251107-05:10:01,46 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile
# 251107-05:10:01,47 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile already exists,41a8106412473b47d3c08da6e8c3f3af, copy:1
# 251107-05:10:01,48 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/logfile already exists, not overwriting, copy:1
# 251107-05:10:01,48 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz
# 251107-05:10:01,49 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/tstat2.nii.gz
# 251107-05:10:01,53 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz
# 251107-05:10:01,55 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists,3174dd250e72ea701ed70052ea448161, copy:1
# 251107-05:10:01,58 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat2.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,59 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-05:10:01,60 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/cope4.nii.gz
# 251107-05:10:01,63 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz
# 251107-05:10:01,67 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists,5ac5549ae60599bb432d18af81015cac, copy:1
# 251107-05:10:01,70 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/cope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,70 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-05:10:01,71 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/pe4.nii.gz
# 251107-05:10:01,74 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz
# 251107-05:10:01,95 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists,5ac5549ae60599bb432d18af81015cac, copy:1
# 251107-05:10:01,100 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/pe4.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,102 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-05:10:01,103 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/zstat3.nii.gz
# 251107-05:10:01,106 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz
# 251107-05:10:01,110 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists,a0ffe586bfa19be150ab68d64328061b, copy:1
# 251107-05:10:01,112 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat3.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,113 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-05:10:01,114 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/zstat1.nii.gz
# 251107-05:10:01,116 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz
# 251107-05:10:01,119 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists,5ef74dd9f9d1637175cfa24a3cba66fe, copy:1
# 251107-05:10:01,122 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/zstat1.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,122 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-05:10:01,123 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/varcope4.nii.gz
# 251107-05:10:01,126 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz
# 251107-05:10:01,129 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists,43a4dfd2a154e561fa599245de79d79f, copy:1
# 251107-05:10:01,131 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/varcope4.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,132 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-05:10:01,133 nipype.utils DEBUG:
# 	 Copying File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz->/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_estimate/results/tstat4.nii.gz
# 251107-05:10:01,135 nipype.utils DEBUG:
# 	 /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz
# 251107-05:10:01,138 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists,aee29affc1e1edc6622acf13173ae653, copy:1
# 251107-05:10:01,140 nipype.utils DEBUG:
# 	 File: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results/tstat4.nii.gz already exists, not overwriting, copy:1
# 251107-05:10:01,142 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 1.335147s.
# 251107-05:10:01,145 nipype.workflow DEBUG:
# 	 Needed files: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.hdr;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.img;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.nii;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.mat;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/model_generation/run0.png;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_0xfa0418743da9daf4cf6fc830a6321f0d_unfinished.json;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_inputs.pklz;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_node.pklz
# 251107-05:10:01,146 nipype.workflow DEBUG:
# 	 Needed dirs: /srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/results;/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report
# 251107-05:10:01,146 nipype.workflow DEBUG:
# 	 Removing files:
# 251107-05:10:01,147 nipype.workflow DEBUG:
# 	 Saving results file: '/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/result_datasink.pklz'
# 251107-05:10:01,150 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/srv/tempdd/egermani/hcp_pipelines/data/derived/fsl_preprocessing/intermediate_results/l1_analysis_fsl/_fwhm_8_hrf_no_derivatives_nb_param_24_subject_id_131823_task_GAMBLING/datasink/_report/report.rst"
# 251107-05:10:01,716 nipype.workflow DEBUG:
# 	 Progress: 14 jobs, 13/1/0 (done/running/ready), 1/0 (pending_tasks/waiting).
# 251107-05:10:01,719 nipype.workflow INFO:
# 	 [Job 13] Completed (l1_analysis_fsl.datasink).
# 251107-05:10:01,723 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 251107-05:10:01,726 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.89/6.89, Free processors: 16/16.
# 251107-05:10:01,728 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock
